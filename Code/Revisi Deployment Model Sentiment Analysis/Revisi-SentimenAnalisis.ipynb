# %% [markdown]
# #**Operasi File.csv**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import re
import nltk
import pickle
import matplotlib.pyplot as plt
import io

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.naive_bayes import MultinomialNB

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
# %cd '/content/drive/MyDrive/Kuliah/Tugas & Materi/Semester 5/Sistem Cerdas/Prak_Avriansyah Bahtiar/Revisi Deployment Model Sentiment Analysis'
# Out:
# /content/drive/MyDrive/Kuliah/Tugas & Materi/Semester 5/Sistem Cerdas/Prak_Avriansyah Bahtiar/Revisi Deployment Model Sentiment Analysis

# %%
from os import read
import csv
with open('datasetnew3.csv') as csvfile:
  readCSV = csv.reader(csvfile, delimiter=',')
  for row in readCSV: #looping perbaris
    print(row)
# Out:
# ['Reviews', 'Rating']
# ['Sebenernya ini aplikasi biasa saja hanya saja, saya mendownload aplikasi ini karena diwajibkan oleh sekolah dan masalahnya aplikasi ini mengambil data pribadi yang tentu saja saya keberatan. Kalau ingin membantu seseorang ayolah membantu dengan ikhlas dan Jagan malah mengambil data pribadi seseorang.', '1']
# ['Kak maaf mau tanya, kan waktu di halaman yang ada tulisan username/emain dan password kok setelah dimasukan kata katanya ke kolom itu waktu mau daftar kok gak bisa daftar y kak, palah ada tulisan username not found', '1']
# ['Aplikasikannya belum siap, loadingnya tidak ada ampun... Lama banget, cape nunggunya... Server over load dan belum siap, persiapkan dulu...', '1']
# ['Aneh padahal daftar sudah benar malah disalahkan,aplikasi tidak bermutu', '1']
# ['Aplikasi tidak guna hanya loading saja.. Padahal sinyal WiFi kencang', '1']
# ['Aplikasi ngelag ga bermutu mau dikasih ratting tinggi? Benerin dulu aplikasinya bos, baru sebarkan. Sampah', '1']
# ['username sudah digunakan padahal udah ganti username yang panjang dan susah tapi tetep ga bisa.', '1']
# ['Ini gimna udh masuk tapi pas logout mau masuk lagi, Pedahal username sama password nya sama BNR tpi not fot mlu', '1']
# ['Kebanyakan Bug. Sangat Mengecewakan', '1']
# ['Susah banget register-nya. Daritadi gagal terus. Tulisannya "Alert: Gagal mendapatkan token".', '1']
# ['Aplikasi sulit di gunakan saya gak suka ribettt banget knp gak daftar ofline saja', '1']
# ['Uhm untuk daftar aja ribet,salah username,emai bermasalah lah..ng jelas', '1']
# ['ribet, saya sekolah diwajibkan mendownload aplikasi ini, padahal kan memori saya penuh, saya kasih rating bintang 1', '1']
# ['Eror Mulu gk bisa login kadang² over load server+ kadang ² loading nya nunggu 1 abat dulu', '1']
# ['Aplikasi nya belum siap,ga bisa daftar masuk', '1']
# ['Aplikasi gk bagus programmer naikin bayarannya jadi 100 juta biar bagus', '1']
# ['Wkwwkwkwk najis lah dipaksa download sama sekolah padahal memori udah penuh tapi tetep dipaksa', '1']
# ['Gak bisa di download Setiap 85%balik lg ke awal', '1']
# ['Bikin apk niat dikit ke lol.. Susah di regis.susah masuk..atau cuman mau colong data doang???', '1']
# ['App cacad hampir beberapa cacad gk beres benerin kek masa org gk bisa masuk', '1']
# ['Install uninstall berkali-kali karena pertama buka button "daftar"nya ga ada dan lgsg diminta login. R u st2pid? Login pake apa coba?!', '1']
# ['Benerin dong aplikasi nya ini mau login susah banget, dan lama', '1']
# ['Aplikasi nya lemot banget lama jadinya', '1']
# ['Ga jls minta reset password malah ga di kirim²', '1']
# ['lemottt.. dari 4jam lalu masih muter2', '1']
# ['Tidak bisa masuk / daftar', '1']
# ['Ini aplikasi apa tidak bisa bikin saya sehat, tidak bisa mabar pula', '1']
# ['Aplikasi nya ngelag plis diperbaiki', '1']
# ['Lemot banget pas mau login', '1']
# ['Gamenya gak seru, kontrolnya ngelag', '1']
# ['Ga guna ada ada aja menuh2n memori aja.. Kalau ga dr skolah ogah bnr..', '1']
# ['Disuruh sekolah ke apk sobat tb malah bikin jadi sobat tambah puyeng ama ini apk', '1']
# ['Apk ga guna. Download karana di suruh dari sekolahan aja,', '1']
# ['Ini game apa gabisa mabar gabisa gacha juga', '1']
# ['Disuruh Bu Setyo download aplikasinya, jadi tolong jadikan brand ambassador', '1']
# ['Lemot banget!!!kalo blm siap jangan dipaksakan donk!!!', '1']
# ['Aplikasi Sobat TB ini bukannya memudahkan malah menyusahkan', '1']
# ['ini APK bisa nya cuma bisa ambil data pribadi doang', '1']
# ['coba dl smg sesuai... br bintang nya di tambah', '1']
# ['Aplikasi nya loding terus, jlek', '1']
# ['aplikasi jelek gabisa mabar', '1']
# ['isinya kata alert semua', '1']
# ['apk nya jelek', '1']
# ['Bilkin ribet hapus aja aplikasi ini bisa bikin aplikasi penting gak sih?', '1']
# ['APLIKASI INI MEMAKSA DAN APLIKASI INI TIDAK ADA GUNA NYA', '1']
# ['Susah masuk karna harus menggunakan email..', '1']
# ['Aplikasi ko jlek bnget dibuka loding mulu', '1']
# ['Apknya b aja,ini krn disuru skolahan ank aja download', '1']
# ['Lama banget aksesnya', '1']
# ['Aplikasi jelek saya jadi kena TBC', '1']
# ['Tidak bisa di download', '1']
# ['aplikasi gak jelas', '1']
# ['Hoax banget!! jangan di download sumpah g guna', '1']
# ['aplikasi nya eror ni', '1']
# ['depoloper jangan sibuk jamsut', '1']
# ['App gk jelas user name sudah digunakan padahal blom digunakan SM sekali', '1']
# ['APK jelek 8 bit gaada pintu', '1']
# ['Apknya kok gini amat', '1']
# ['aplikasi nya kaya anus', '1']
# ['Gw kok positiv tbc cok? Pdhal cuman rokok 1x', '1']
# ['Ribet Banget Nih Aplikasi', '1']
# ['Hehehe..... Jamsut dulu masseh', '1']
# ['Apk sangat buruk', '1']
# ['Login lama banget', '1']
# ['Lebih percaya joko kendil naik macan putih', '1']
# ['Aplikasi nya eror', '1']
# ['SAYA MALAS KARENA DISURUH SEKOLAH', '1']
# ['Ga bisa dibuka. Payah', '1']
# ['pengambilan data pribadi', '1']
# ['Jelek kaya said', '1']
# ['Gatau pengen aja', '1']
# ['Hapus aja apk nya', '1']
# ['aplikasi rusak ga jelas', '1']
# ['Pemaksaan download asu', '1']
# ['Susah download nya', '1']
# ['apk gk jelas', '1']
# ['Bangke ye kouta gw abis , APK cacat', '1']
# ['apk boren gabisa mabar', '1']
# ['Apk cacat loading doang', '1']
# ['Loading Lama banget', '1']
# ['Lemot', '1']
# ['Susah login', '1']
# ['Aplikasi eror', '1']
# ['iyuh jelek banget, tampilannya kurang banget deh', '1']
# ['Loading mulu', '1']
# ['Apk ngga jelas', '1']
# ['ngga dulu deh', '1']
# ['Susah masuk', '1']
# ['GK jelas', '1']
# ['Aplikasi jelek', '1']
# ['Ngelag banget', '1']
# ['aplikasi gajelas', '1']
# ['Aplikasi sampah', '1']
# ['Jelek', '1']
# ['Lemot!!!', '1']
# ['Gk guna!!', '1']
# ['Aplikasi jelek', '1']
# ['hoaxx!!!', '1']
# ['Server sering load / stuck di loading', '1']
# ['Kok GK bisa di download sih', '1']
# ['ngelek ngelek uninstal ajaaa', '1']
# ['Lama banget', '1']
# ['Lamat bat', '1']
# ['Jelek banget apk nya', '1']
# ['Ngeleg cok', '1']
# ['Gabisa di download', '1']
# ['Moon maaf', '1']
# ['Aplikasi sampah', '1']
# ['Gak enak', '1']
# ['Apknya tidak baik', '1']
# ['Sering loading', '1']
# ['Apk gaguna', '1']
# ['jelek', '1']
# ['kurang puas', '1']
# ['Ngga bagus', '1']
# ['Lemot', '1']
# ['Jelek', '1']
# ['apknya gajelas', '1']
# ['ngga berguna', '1']
# ['maaf banget tapi aplikasinya kurang banget, soalnya sering banget ngelag dan banyak halangan lainnya', '1']
# ['Download nya kalo nga ditunggu nga bisa download, jadii ribet ini aja belum masuk juga ke apknya', '1']
# ['Login nya lama banget mana error mulu', '1']
# ['Lemood diakses ya susah', '1']
# ['download nya lama banget', '1']
# ['Aplikasi ini sangat lambat dalam memuat konten.', '1']
# ['Antarmuka pengguna terlalu rumit, membuatnya sulit untuk navigasi.', '1']
# ['Beberapa artikel terasa usang dan tidak terlalu relevan.', '1']
# ['Fitur pencarian tidak efektif, sulit menemukan informasi spesifik.', '1']
# ['Tidak ada pembaruan konten untuk waktu yang lama.', '1']
# ['Terdapat bug yang membuat aplikasi sering crash.', '1']
# ['Tampilan grafis terlalu kuno dan tidak menarik.', '1']
# ['Pemahaman tentang gejala TBC terasa kurang mendalam.', '1']
# ['Konten aplikasi tidak memadai untuk kebutuhan pengguna yang ingin informasi lebih mendalam.', '1']
# ['Tidak ada opsi untuk menyimpan atau bookmark artikel favorit.', '1']
# ['Tidak ada dukungan untuk banyak bahasa, membuatnya terbatas dalam jangkauan.', '1']
# ['Aplikasi sering mengalami gangguan koneksi, bahkan dengan sinyal yang baik.', '1']
# ['Pemberitahuan tidak selalu bekerja dengan baik atau terlalu sering muncul.', '1']
# ['Kurangnya interaktivitas, seperti forum diskusi atau pertanyaan dan jawaban.', '1']
# ['Tidak ada pembaruan untuk memperbaiki kesalahan ketik atau kesalahan faktual yang terdapat dalam konten.', '1']
# ['Panduan pengobatan terasa terlalu umum, tanpa detail yang cukup.', '1']
# ['Tidak ada integrasi dengan sumber informasi medis eksternal.', '1']
# ['Tidak ada opsi untuk berlangganan konten premium untuk mendapatkan informasi eksklusif.', '1']
# ['Tidak ada informasi tentang riset terbaru dalam pengobatan TBC.', '1']
# ['Konten aplikasi terlalu statis dan tidak responsif terhadap perkembangan baru.', '1']
# ['Penggunaan istilah medis yang sulit dipahami bagi orang awam.', '1']
# ['Tidak ada pembaruan untuk memperbaiki tautan yang rusak.', '1']
# ['Aplikasi kurang memberikan solusi praktis untuk penderita TBC sehari-hari.', '1']
# ['Tidak adanya panduan visual, seperti video edukatif atau diagram.', '1']
# ['Tidak ada opsi untuk memberikan umpan balik langsung pada konten.', '1']
# ['Tidak ada peringatan atau informasi kesehatan darurat yang disertakan.', '1']
# ['Aplikasi terlalu bergantung pada teks, tanpa elemen interaktif yang menarik.', '1']
# ['Tidak ada pengingat untuk minum obat atau mengikuti rencana pengobatan.', '1']
# ['Fitur peta untuk menemukan fasilitas kesehatan terdekat tidak berfungsi dengan baik.', '1']
# ['Aplikasi kurang memberikan perhatian pada aspek psikologis penderita TBC.', '1']
# ['Tidak ada opsi untuk berbagi konten melalui media sosial.', '1']
# ['Tidak ada pembaruan untuk mencakup panduan kesehatan terkini.', '1']
# ['Panduan pengobatan terasa terlalu umum, tanpa detail yang cukup.', '1']
# ['Tidak ada integrasi dengan sumber informasi medis eksternal.', '1']
# ['Tidak ada opsi untuk berlangganan konten premium untuk mendapatkan informasi eksklusif.', '1']
# ['Tidak ada informasi tentang riset terbaru dalam pengobatan TBC.', '1']
# ['Konten aplikasi terlalu statis dan tidak responsif terhadap perkembangan baru.', '1']
# ['Penggunaan istilah medis yang sulit dipahami bagi orang awam.', '1']
# ['Tidak ada pembaruan untuk memperbaiki tautan yang rusak.', '1']
# ['Aplikasi kurang memberikan solusi praktis untuk penderita TBC sehari-hari.', '1']
# ['Tidak adanya panduan visual, seperti video edukatif atau diagram.', '1']
# ['Tidak ada opsi untuk memberikan umpan balik langsung pada konten.', '1']
# ['Tidak ada peringatan atau informasi kesehatan darurat yang disertakan.', '1']
# ['Aplikasi terlalu bergantung pada teks, tanpa elemen interaktif yang menarik.', '1']
# ['Tidak ada pengingat untuk minum obat atau mengikuti rencana pengobatan.', '1']
# ['Fitur peta untuk menemukan fasilitas kesehatan terdekat tidak berfungsi dengan baik.', '1']
# ['Aplikasi kurang memberikan perhatian pada aspek psikologis penderita TBC.', '1']
# ['Tidak ada opsi untuk berbagi konten melalui media sosial.', '1']
# ['Tidak ada pembaruan untuk mencakup panduan kesehatan terkini.', '1']
# ['Kurangnya informasi tentang penanganan TBC pada kelompok rentan.', '1']
# ['Tidak ada opsi untuk mencari informasi berdasarkan tingkat keparahan gejala.', '1']
# ['Tidak ada dukungan untuk versi aplikasi yang lebih lama.', '1']
# ['Konten aplikasi terlalu ringkas dan tidak cukup mendalam.', '1']
# ['Tidak ada opsi untuk mendownload konten untuk akses offline.', '1']
# ['Tidak ada panduan untuk mendukung keluarga penderita TBC.', '1']
# ['Aplikasi tidak berfokus pada pencegahan TBC di masyarakat.', '1']
# ['Tidak adanya peringatan privasi atau kebijakan keamanan data yang jelas.', '1']
# ['Tidak ada sumber referensi eksternal untuk mendukung informasi yang disajikan.', '1']
# ['Tidak ada panduan tentang cara mengatasi efek samping obat TBC.', '1']
# ['Fitur pencarian tidak memiliki opsi filter atau kategori.', '1']
# ['Konten aplikasi terlalu berat pada aspek medis dan kurang ramah untuk pemahaman umum.', '1']
# ['Tidak ada opsi untuk menghubungi tim dukungan pengguna.', '1']
# ['Tidak ada opsi untuk menyimpan riwayat pencarian atau pembacaan.', '1']
# ['Tidak ada informasi tentang dukungan finansial bagi penderita TBC.', '1']
# ['Fitur terkait nutrisi dan diet terasa kurang mendalam dan kurang praktis.', '1']
# ['Konten aplikasi cenderung bersifat teoritis dan kurang menggambarkan kasus-kasus nyata.', '1']
# ['Tidak ada opsi untuk melihat pertanyaan umum atau panduan cepat.', '1']
# ['Tidak ada pilihan untuk menyaring informasi berdasarkan wilayah geografis.', '1']
# ['Konten tidak mencakup informasi tentang pengobatan alternatif.', '1']
# ['Tidak ada dukungan untuk integrasi dengan perangkat wearable kesehatan.', '1']
# ['Tidak ada tautan langsung atau integrasi dengan organisasi kesehatan terkemuka.', '1']
# ['Aplikasi kurang mengakomodasi kebutuhan individu dengan tingkat literasi yang berbeda.', '1']
# ['Tidak adanya opsi untuk memberikan umpan balik langsung tentang pengalaman pengguna.', '1']
# ['Fitur interaktif, seperti kuis atau permainan pendidikan, tidak tersedia.', '1']
# ['Tidak adanya opsi untuk menyaring informasi berdasarkan kelompok usia.', '1']
# ['Konten aplikasi tidak diupdate dengan tren dan gaya desain terkini.', '1']
# ['Tidak ada opsi untuk mengakses konten terkait dengan pandemi TBC global.', '1']
# ['Aplikasi terlalu fokus pada aspek medis dan kurang pada aspek psikososial.', '1']
# ['Tidak ada opsi untuk mencari spesialis atau dokter kesehatan terkait TBC.', '1']
# ['Konten aplikasi terlalu serius dan kurang menggambarkan harapan positif.', '1']
# ['Tidak ada opsi untuk mendapatkan bimbingan dari ahli melalui sesi online.', '1']
# ['Tidak adanya dukungan untuk forum atau komunitas pengguna.', '1']
# ['Aplikasi sering mengalami kendala teknis yang mengganggu pengalaman pengguna.', '1']
# ['Tidak ada pembaruan untuk mencakup informasi tentang vaksinasi TBC terkini.', '1']
# ['Tidak adanya opsi untuk menghubungi pusat darurat kesehatan melalui aplikasi.', '1']
# ['Konten aplikasi terlalu teks berat dan kurang menarik visualnya.', '1']
# ['Tidak ada opsi untuk mendapatkan informasi melalui chat langsung.', '1']
# ['Fitur pemberitahuan sering kali tidak sesuai dengan preferensi pengguna.', '1']
# ['Tidak adanya opsi untuk mencari informasi berdasarkan gejala spesifik.', '1']
# ['Konten aplikasi kurang mendukung untuk individu dengan keterbatasan kognitif.', '1']
# ['Tidak ada pembaruan untuk memperbaiki link yang mengarah ke situs eksternal.', '1']
# ['Tidak ada integrasi dengan layanan konsultasi medis online.', '1']
# ['Konten aplikasi cenderung terlalu teknis, sulit dipahami oleh umum.', '1']
# ['Tidak ada opsi untuk menyaring konten berdasarkan tingkat pengetahuan pengguna.', '1']
# ['Tidak adanya panduan langkah demi langkah untuk pemeriksaan diri TBC.', '1']
# ['Konten aplikasi terlalu umum dan kurang terfokus pada isu-isu khusus.', '1']
# ['Tidak ada opsi untuk memperbarui preferensi notifikasi pengguna.', '1']
# ['Tidak ada fitur untuk mengakses testimoni penderita TBC.', '1']
# ['Konten aplikasi terlalu minimalis dan tidak memadai untuk mendukung kebutuhan pengguna.', '1']
# ['Tidak ada opsi untuk berlangganan artikel atau mendapatkan pembaruan berkala.', '1']
# ['Fitur pencarian tidak dapat menangani pertanyaan yang kompleks.', '1']
# ['Konten aplikasi tidak mencakup informasi tentang rehabilitasi pasien TBC.', '1']
# ['Tidak ada opsi untuk mengakses panduan untuk keluarga yang merawat penderita TBC.', '1']
# ['Tidak ada dukungan untuk penyesuaian teks atau kontrast visual.', '1']
# ['Konten aplikasi kurang menyentuh tentang stigma sosial seputar TBC.', '1']
# ['Tidak ada pembaruan untuk memasukkan perspektif pasien dalam konten.', '1']
# ['Tidak adanya opsi untuk menyusun rencana pencegahan TBC di rumah.', '1']
# ['Konten aplikasi cenderung terlalu serius dan kurang ramah.', '1']
# ['Tidak ada integrasi dengan program-program kesadaran TBC di seluruh dunia.', '1']
# ['Tidak ada opsi untuk melihat ulasan atau peringkat dari pengguna lain.', '1']
# ['Konten aplikasi tidak mencakup informasi tentang pendekatan holistik terhadap TBC.', '1']
# ['Tidak ada opsi untuk mengakses materi edukasi khusus untuk kelompok usia tertentu.', '1']
# ['Tidak adanya opsi untuk memfilter konten berdasarkan tingkat keparahan TBC.', '1']
# ['Konten aplikasi tidak cukup mendukung bagi individu dengan kebutuhan kesehatan khusus.', '1']
# ['Tidak ada pembaruan untuk mencakup informasi tentang kesehatan mental penderita TBC.', '1']
# ['Tidak ada opsi untuk melihat kisah sukses atau perjalanan kesembuhan penderita TBC.', '1']
# ['Konten aplikasi terlalu teoritis dan kurang terfokus pada solusi praktis.', '1']
# ['Tidak ada opsi untuk menyaring konten berdasarkan penyebab atau faktor risiko TBC.', '1']
# ['Tidak adanya fitur untuk menghubungkan pengguna dengan kelompok pendukung lokal.', '1']
# ['Konten aplikasi tidak mencakup informasi tentang program-program penanggulangan TBC di komunitas.', '1']
# ['Tidak ada pembaruan untuk menyertakan informasi tentang pengobatan alternatif yang populer.', '1']
# ['Tidak ada opsi untuk berlangganan buletin untuk mendapatkan pembaruan terbaru tentang TBC.', '1']
# ['Konten aplikasi cenderung terlalu medis dan kurang memberikan pemahaman holistik tentang TBC.', '1']
# ['Tidak adanya opsi untuk berlangganan layanan konsultasi medis online terkait TBC.', '1']
# ['Tidak ada fitur untuk mengirimkan pertanyaan langsung kepada tim ahli medis melalui aplikasi.', '1']
# ['Konten aplikasi kurang bersifat dinamis, tanpa opsi interaktif yang menarik pengguna.', '1']
# ['Tidak ada pembaruan untuk mencakup informasi tentang kebijakan pencegahan TBC di tingkat pemerintahan.', '1']
# ['Tidak ada opsi untuk menghubungi nomor darurat kesehatan melalui aplikasi.', '1']
# ['Konten aplikasi cenderung terlalu kering dan kurang mencakup cerita penderita TBC.', '1']
# ['Tidak ada integrasi dengan platform media sosial untuk berbagi informasi atau kampanye kesadaran TBC.', '1']
# ['Tidak ada pembaruan untuk mencakup informasi tentang pengobatan TBC pada populasi lansia.', '1']
# ['Tidak ada opsi untuk mendapatkan bimbingan dari ahli nutrisi untuk mendukung pengobatan TBC.', '1']
# ['Konten aplikasi tidak mencakup informasi tentang penelitian terkini dalam pengobatan TBC.', '1']
# ['Tidak ada pembaruan untuk mencakup panduan untuk melibatkan masyarakat dalam upaya pencegahan TBC.', '1']
# ['Tidak ada opsi untuk mengakses materi edukasi yang disesuaikan dengan kebutuhan kelompok usia anak-anak.', '1']
# ['Konten aplikasi terlalu kaku dan tidak cukup memberikan empati kepada penderita TBC.', '1']
# ['Tidak ada opsi untuk menyusun rencana pemulihan atau tindak lanjut setelah pengobatan TBC selesai.', '1']
# ['Tidak adanya opsi untuk mencari penyedia layanan kesehatan yang spesifik terkait TBC.', '1']
# ['Konten aplikasi kurang mencakup informasi tentang dampak ekonomi bagi penderita TBC.', '1']
# ['Tidak ada pembaruan untuk memasukkan perspektif masyarakat dalam konten.', '1']
# ['Tidak ada opsi untuk mencari informasi tentang kebijakan kesehatan terkait TBC di berbagai negara.', '1']
# ['Tidak ada fitur untuk menghubungkan pengguna dengan kelompok dukungan online untuk penderita TBC.', '1']
# ['Konten aplikasi kurang mendukung bagi keluarga yang ingin memahami peran mereka dalam merawat penderita TBC.', '1']
# ['Tidak ada opsi untuk mengakses webinar atau konferensi online tentang TBC.', '1']
# ['Tidak adanya fitur untuk menghubungkan pengguna dengan organisasi amal terkait TBC.', '1']
# ['jelek', '1']
# ['jelek banget sumpah', '1']
# ['Konten aplikasi cenderung terlalu umum dan tidak memberikan panduan spesifik untuk kondisi TBC yang kompleks.', '1']
# ['tersehat lo deh sampah', '1']
# ['Tidak ada pembaruan untuk mencakup informasi tentang perawatan kesehatan mental bagi penderita TBC.', '1']
# ['Sangat kecewa dengan aplikasi ini, sering kali crash tanpa alasan.', '1']
# ['Antarmuka pengguna sangat buruk, sulit untuk mencari informasi yang dibutuhkan.', '1']
# ['Aplikasi sering kali tidak merespons, membuat pengguna frustasi.', '1']
# ['Saya mengalami masalah koneksi yang konstan, sulit untuk mengakses konten.', '1']
# ['Tidak ada pembaruan konten yang relevan, membuat aplikasi terasa usang.', '1']
# ['Fitur pencarian tidak berguna, sulit menemukan informasi yang diinginkan.', '1']
# ['Aplikasi ini penuh dengan iklan mengganggu yang membuat pengalaman pengguna buruk.', '1']
# ['Navigasi yang sangat sulit dimengerti, membuat saya tidak nyaman menggunakan aplikasi.', '1']
# ['Tidak ada dukungan pelanggan yang responsif, sulit mendapatkan bantuan.', '1']
# ['Sangat disayangkan, aplikasi ini sepertinya tidak pernah diperbarui.', '1']
# ['Informasi yang disajikan tidak akurat, membuat saya ragu dengan keandalan aplikasi ini.', '1']
# ['Tidak ada fitur keamanan yang memadai, membuat saya khawatir tentang privasi saya.', '1']
# ['Aplikasi sering kali hang, membuatnya tidak mungkin untuk digunakan.', '1']
# ['Tidak ada panduan pengguna yang jelas, sulit untuk memahami cara menggunakan aplikasi.', '1']
# ['Konten yang tersedia sangat terbatas, membuat aplikasi ini tidak berharga.', '1']
# ['Saya kecewa dengan kurangnya respons dari pengembang terhadap masukan pengguna.', '1']
# ['Aplikasi ini tampaknya tidak dioptimalkan dengan baik untuk perangkat saya.', '1']
# ['Saya menemui banyak bug yang tidak kunjung diperbaiki, membuat pengalaman semakin buruk.', '1']
# ['Sangat sulit untuk berinteraksi dengan pengguna lain, tidak ada fitur komunitas yang baik.', '1']
# ['Pembaruan aplikasi ini tidak membawa perubahan yang signifikan, merasa sia-sia.', '1']
# ['Tidak ada opsi kustomisasi yang memadai, membuat pengguna merasa terikat.', '1']
# ['Aplikasi ini terlalu lambat, butuh waktu lama untuk memuat halaman.', '1']
# ['Tidak ada pembaruan fitur yang berarti, membuat aplikasi terasa usang.', '1']
# ['Sistem notifikasi sangat mengganggu, sering kali memberikan pemberitahuan yang tidak relevan.', '1']
# ['Sangat disayangkan melihat potensi aplikasi ini tidak digarap dengan baik.', '1']
# ['Aplikasi ini seharusnya tidak rilis dalam kondisi ini, masih banyak bug yang perlu diperbaiki.', '1']
# ['Tidak ada integrasi dengan platform lain, membuat aplikasi terasa terpencil.', '1']
# ['Sistem pelaporan bug tidak berfungsi dengan baik, sulit untuk memberikan umpan balik.', '1']
# ['Saya merasa sangat tidak puas dengan kualitas konten yang disediakan.', '1']
# ['Aplikasi ini tampaknya tidak kompatibel dengan perangkat saya, sering kali crash.', '1']
# ['Kurangnya tutorial membuatnya sulit bagi pengguna baru untuk memahami fungsionalitasnya.', '1']
# ['Sangat disayangkan melihat aplikasi ini merosot sejauh ini.', '1']
# ['Tidak ada pilihan untuk mengatur preferensi pengguna, membuat pengalaman pengguna terbatas.', '1']
# ['Sistem evaluasi konten sangat buruk, banyak informasi yang tidak terverifikasi.', '1']
# ['Sangat sulit untuk memberikan umpan balik, tidak ada saluran komunikasi yang jelas.', '1']
# ['Aplikasi ini sepertinya tidak mengutamakan keamanan data pengguna.', '1']
# ['Fitur pencarian membantu pengguna menemukan informasi dengan cepat.', '3']
# ['Dapat diandalkan sebagai referensi awal untuk informasi tentang TBC.', '3']
# ['Tersedia dalam beberapa bahasa, memungkinkan akses global.', '3']
# ['Grafik dan ilustrasi membantu menjelaskan informasi dengan lebih baik.', '3']
# ['Aplikasi memberikan panduan langkah demi langkah untuk penanganan TBC.', '3']
# ['Menghadirkan informasi medis dengan bahasa yang mudah dipahami.', '3']
# ['Tidak terlalu membingungkan bagi orang yang awam dengan istilah medis.', '3']
# ['Pembaruan konten secara berkala dapat meningkatkan nilai aplikasi.', '3']
# ['Tersedia offline, memungkinkan akses tanpa koneksi internet.', '3']
# ['Integrasi dengan sumber informasi medis terkini akan meningkatkan validitas.', '3']
# ['Aplikasi memberikan saran praktis untuk mencegah penyebaran TBC.', '3']
# ['hmmmm….. Suka tapi suka sebel', '3']
# ['Statistik dan data yang disajikan dengan jelas.', '3']
# ['Pengguna dapat berpartisipasi dalam forum atau diskusi.', '3']
# ['Aplikasi memberikan informasi tentang gejala TBC dengan rinci.', '3']
# ['Mudah diakses oleh semua kalangan, termasuk pengguna lansia.', '3']
# ['Tersedia untuk beberapa platform, meningkatkan aksesibilitas.', '3']
# ['Aplikasi memberikan informasi tentang obat-obatan yang umumnya digunakan.', '3']
# ['Format artikel membantu pengguna untuk mendapatkan informasi secara terstruktur.', '3']
# ['Tersedia petunjuk praktis untuk pengobatan di rumah.', '3']
# ['Aplikasi memberikan informasi tentang vaksinasi TBC.', '3']
# ['Memberikan pemahaman yang cukup baik tentang perbedaan antara TB aktif dan laten.', '3']
# ['Mengenalkan konsep penyebab dan penyebaran TBC dengan baik.', '3']
# ['Aplikasi dapat menjadi panduan awal yang baik bagi penderita TBC.', '3']
# ['Menyajikan informasi dengan bahasa yang netral dan tidak memihak.', '3']
# ['Dapat diandalkan untuk pemahaman dasar tentang TBC.', '3']
# ['Aplikasi memberikan informasi tentang tempat pelayanan kesehatan terdekat.', '3']
# ['Tersedia opsi untuk menghubungi profesional medis melalui aplikasi.', '3']
# ['Memberikan informasi tentang penelitian terbaru mengenai TBC.', '3']
# ['Aplikasi memberikan informasi tentang risiko penularan TBC di berbagai lingkungan.', '3']
# ['Tersedia opsi untuk berlangganan newsletter untuk mendapatkan pembaruan.', '3']
# ['Panduan untuk mendeteksi dini gejala TBC sangat membantu.', '3']
# ['Tampilan aplikasi cukup menarik tanpa terlalu banyak hiasan.', '3']
# ['Menyediakan opsi untuk menyimpan artikel atau informasi yang penting.', '3']
# ['Aplikasi tidak mengandung informasi yang terlalu teknis.', '3']
# ['Tersedia ulasan atau testimoni pengguna untuk memberikan perspektif tambahan.', '3']
# ['Memberikan informasi tentang peran vaksinasi dalam pencegahan TBC.', '3']
# ['Aplikasi menyajikan informasi tentang kondisi kesehatan yang bisa memperburuk TBC.', '3']
# ['Tersedia daftar pertanyaan umum yang dijawab dengan baik.', '3']
# ['Aplikasi dapat membantu mengurangi stigmatisasi seputar TBC.', '3']
# ['Penyajian informasi yang terstruktur membuatnya mudah diikuti.', '3']
# ['Menyediakan opsi untuk menghubungi tenaga medis melalui chat.', '3']
# ['Tampilan aplikasi responsif dan tidak mengalami lag.', '3']
# ['Memberikan pandangan tentang dampak sosial TBC.', '3']
# ['Tersedia informasi tentang cara mendukung individu dengan TBC.', '3']
# ['Aplikasi menyajikan informasi tentang penelitian terkini dalam bahasa yang sederhana.', '3']
# ['Memberikan informasi tentang pemeriksaan dan diagnosis TBC.', '3']
# ['Tersedia opsi untuk menyumbangkan atau mendukung organisasi kesehatan.', '3']
# ['Menyajikan informasi tentang penularan TBC di kalangan anak-anak.', '3']
# ['Tersedia opsi untuk mengajukan pertanyaan kepada ahli melalui aplikasi.', '3']
# ['Memberikan informasi tentang langkah-langkah pencegahan di tempat kerja.', '3']
# ['Aplikasi memberikan perspektif tentang rehabilitasi pasien TBC.', '3']
# ['Tersedia fitur untuk memeriksa gejala secara mandiri.', '3']
# ['Memberikan informasi tentang perawatan kesehatan mental bagi penderita TBC.', '3']
# ['Aplikasi menyajikan informasi tentang pengaruh rokok terhadap TBC.', '3']
# ['Tersedia opsi untuk berlangganan konten eksklusif.', '3']
# ['Menyediakan daftar organisasi yang dapat memberikan dukungan.', '3']
# ['Aplikasi memberikan panduan bagi keluarga yang merawat penderita TBC.', '3']
# ['Tersedia opsi untuk memberikan umpan balik atau saran.', '3']
# ['Memberikan informasi tentang tindak lanjut setelah selesai pengobatan.', '3']
# ['Menyajikan informasi tentang dampak TBC terhadap sistem kekebalan tubuh.', '3']
# ['Tersedia opsi untuk berbagi informasi melalui media sosial.', '3']
# ['Memberikan informasi tentang jenis-jenis pengobatan yang tersedia.', '3']
# ['Aplikasi menyajikan statistik kejadian TBC di berbagai wilayah.', '3']
# ['Tersedia opsi untuk mencari fasilitas kesehatan yang melayani TBC.', '3']
# ['Memberikan panduan bagi mereka yang melakukan perjalanan ke daerah risiko.', '3']
# ['Menyajikan informasi tentang program pencegahan TBC di masyarakat.', '3']
# ['Tersedia opsi untuk mengakses materi edukasi untuk penyuluhan.', '3']
# ['Memberikan informasi tentang konsekuensi jangka panjang dari TBC.', '3']
# ['Aplikasi memberikan gambaran tentang situasi TBC global.', '3']
# ['Tersedia opsi untuk mengunduh materi informasi sebagai referensi.', '3']
# ['Menyajikan informasi tentang peran nutrisi dalam mendukung pengobatan TBC.', '3']
# ['Memberikan pemahaman tentang dampak ekonomi dari TBC.', '3']
# ['Aplikasi memberikan informasi tentang upaya global untuk memerangi TBC.', '3']
# ['Tersedia opsi untuk menghubungi kelompok dukungan pasien TBC.', '3']
# ['Memberikan informasi tentang risiko penularan TBC melalui kontak dekat.', '3']
# ['Menyajikan informasi tentang penanggulangan TBC di fasilitas penjara.', '3']
# ['Aplikasi memberikan panduan bagi pasangan yang ingin memiliki anak dengan TBC.', '3']
# ['Tersedia opsi untuk berpartisipasi dalam survei untuk meningkatkan aplikasi.', '3']
# ['Memberikan informasi tentang peran pemerintah dalam penanganan TBC.', '3']
# ['Menyajikan informasi tentang inovasi pengobatan TBC.', '3']
# ['Tersedia opsi untuk menilai risiko terkena TBC berdasarkan lokasi geografis.', '3']
# ['Aplikasi memberikan panduan untuk memahami hasil tes TBC.', '3']
# ['Memberikan informasi tentang kemungkinan komplikasi selama pengobatan.', '3']
# ['Tersedia opsi untuk berbagi pengalaman pribadi dengan TBC.', '3']
# ['Menyajikan informasi tentang dukungan finansial bagi penderita TBC.', '3']
# ['Aplikasi memberikan pemahaman tentang hubungan antara HIV dan TBC.', '3']
# ['Tersedia opsi untuk menandai artikel favorit untuk referensi cepat.', '3']
# ['Memberikan informasi tentang cara mendukung kampanye kesadaran TBC.', '3']
# ['Menyajikan informasi tentang penanggulangan TBC di lingkungan sekolah.', '3']
# ['Tersedia opsi untuk mendapatkan informasi melalui pemberitahuan.', '3']
# ['Aplikasi memberikan panduan bagi mereka yang ingin berkontribusi dalam riset TBC.', '3']
# ['Gimana dah kadang bener kadang ngga', '3']
# ['Memberikan informasi tentang tata cara pemeriksaan TBC rutin.', '3']
# ['Tersedia opsi untuk mencari bantuan keuangan bagi penderita TBC.', '3']
# ['Menyajikan informasi tentang upaya masyarakat dalam memerangi TBC.', '3']
# ['Aplikasi memberikan panduan bagi individu yang berisiko tinggi terkena TBC.', '3']
# ['Tersedia opsi untuk menghubungi tim dukungan pelanggan aplikasi.', '3']
# ['Mantap', '3']
# ['Standart', '3']
# ['biasa aja bagi gua', '3']
# ['Aplikasi ini menyediakan informasi dasar tentang TBC dengan jelas.', '3']
# ['Antarmuka pengguna cukup sederhana dan mudah dinavigasi.', '3']
# ['Konten aplikasi mencakup berbagai aspek TBC secara umum.', '3']
# ['Beberapa bagian antarmuka mungkin memerlukan peningkatan tata letak.', '3']
# ['Aplikasi memberikan wawasan tentang gejala dan penanganan TBC.', '3']
# ['Terdapat sejumlah besar artikel informatif tentang TBC.', '3']
# ['Pilihan pencarian membantu menemukan informasi dengan mudah.', '3']
# ['Beberapa artikel mungkin perlu pembaruan untuk tetap relevan.', '3']
# ['Aplikasi ini memberikan gambaran umum tentang penyebab dan penyebaran TBC.', '3']
# ['Grafik dan ilustrasi membantu memahami informasi dengan lebih baik.', '3']
# ['Tersedia dalam beberapa bahasa, memungkinkan akses global.', '3']
# ['Informasi tentang pengobatan TBC disajikan secara cukup lengkap.', '3']
# ['Beberapa artikel mungkin terlalu teknis bagi pengguna non-medis.', '3']
# ['Aplikasi memberikan informasi tentang risiko penularan di berbagai lingkungan.', '3']
# ['Integrasi dengan sumber informasi medis terkini akan menjadi nilai tambah.', '3']
# ['Pembaruan konten secara teratur akan meningkatkan relevansi aplikasi.', '3']
# ['Konten aplikasi dapat diperluas untuk mencakup aspek-aspek regional.', '3']
# ['Menyajikan informasi tentang vaksinasi TBC dengan baik.', '3']
# ['Responsivitas antarmuka pengguna perlu ditingkatkan.', '3']
# ['Aplikasi ini memberikan panduan umum tentang pencegahan TBC.', '3']
# ['Menyediakan informasi tentang peran lingkungan dalam penanggulangan TBC.', '3']
# ['Tidak adanya elemen interaktif atau kuis dapat meningkatkan keterlibatan pengguna.', '3']
# ['Aplikasi ini memberikan wawasan tentang pengaruh TBC terhadap kehamilan.', '3']
# ['Konten aplikasi dapat lebih variatif dan menyesuaikan dengan kebutuhan pengguna.', '3']
# ['Tersedia opsi untuk menghubungi dukungan pelanggan jika diperlukan.', '3']
# ['Informasi tentang kebijakan kesehatan global terkait TBC cukup informatif.', '3']
# ['Sejumlah besar informasi disajikan dengan cara yang terstruktur.', '3']
# ['Beberapa fitur seperti bookmarking dapat memberikan nilai tambah.', '3']
# ['Aplikasi ini memberikan panduan tentang perawatan diri selama pengobatan.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat umum.', '3']
# ['Konten aplikasi dapat lebih terfokus pada aspek psikososial TBC.', '3']
# ['Grafik atau diagram dapat membantu visualisasi informasi dengan lebih baik.', '3']
# ['Terdapat opsi untuk berpartisipasi dalam kampanye kesadaran TBC.', '3']
# ['Integrasi dengan layanan konsultasi medis online akan berguna.', '3']
# ['Aplikasi ini memberikan informasi tentang peran nutrisi dalam pengobatan.', '3']
# ['Konten aplikasi dapat diorganisir dengan lebih baik untuk memudahkan pemahaman.', '3']
# ['Respons notifikasi perlu ditingkatkan agar sesuai dengan preferensi pengguna.', '3']
# ['Menyajikan informasi tentang riset terbaru dalam pengobatan TBC.', '3']
# ['Tersedia opsi untuk berlangganan pembaruan berkala melalui email.', '3']
# ['Aplikasi memberikan panduan tentang cara mendukung penderita TBC secara emosional.', '3']
# ['Konten aplikasi mencakup informasi tentang dampak ekonomi bagi penderita.', '3']
# ['Informasi tentang peran keluarga dalam merawat penderita TBC disajikan dengan baik.', '3']
# ['Tersedia opsi untuk berbagi informasi atau artikel melalui media sosial.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di kalangan anak-anak.', '3']
# ['Integrasi dengan forum atau komunitas online akan meningkatkan interaksi pengguna.', '3']
# ['Aplikasi ini memberikan wawasan tentang stigma sosial seputar TBC.', '3']
# ['Fitur pencarian dapat ditingkatkan dengan penambahan filter atau kategori.', '3']
# ['Konten aplikasi memberikan pemahaman tentang perawatan kesehatan mental.', '3']
# ['Tersedia opsi untuk menyusun rencana pemulihan setelah pengobatan selesai.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat kerja.', '3']
# ['Konten aplikasi dapat lebih menggambarkan kasus-kasus nyata penderita TBC.', '3']
# ['Responsivitas antarmuka dapat dioptimalkan untuk perangkat seluler.', '3']
# ['Menyediakan informasi tentang risiko penularan TBC di fasilitas umum.', '3']
# ['Integrasi dengan webinar atau konferensi online dapat memberikan nilai tambah.', '3']
# ['Aplikasi ini memberikan panduan untuk memahami hasil tes TBC.', '3']
# ['Tersedia opsi untuk menghubungi tim dukungan pelanggan aplikasi.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di komunitas terbatas.', '3']
# ['Respons notifikasi dapat disesuaikan lebih lanjut sesuai preferensi pengguna.', '3']
# ['Konten aplikasi dapat memperhatikan penyampaian informasi dengan lebih ringkas.', '3']
# ['Menyediakan informasi tentang risiko penularan TBC di lingkungan rumah.', '3']
# ['Tersedia opsi untuk mengakses sumber daya tambahan untuk mendukung penderita.', '3']
# ['Konten aplikasi dapat memasukkan lebih banyak studi kasus penderita TBC.', '3']
# ['Integrasi dengan layanan konsultasi medis online terkait TBC dapat ditingkatkan.', '3']
# ['Aplikasi ini memberikan panduan untuk mendukung program vaksinasi TBC di komunitas.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di lingkungan transportasi.', '3']
# ['Tersedia opsi untuk berpartisipasi dalam kegiatan olahraga atau acara kesadaran TBC.', '3']
# ['Konten aplikasi dapat disusun berdasarkan tingkat keparahan TBC.', '3']
# ['Integrasi dengan media sosial dapat ditingkatkan untuk mendukung kampanye kesadaran.', '3']
# ['Aplikasi ini memberikan wawasan tentang risiko penularan TBC di lingkungan sekolah.', '3']
# ['Responsivitas antarmuka pengguna dapat ditingkatkan pada situasi koneksi yang lambat.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di fasilitas pelayanan kesehatan.', '3']
# ['Tersedia opsi untuk mengakses webinar atau seminar online tentang TBC.', '3']
# ['Konten aplikasi dapat lebih mendukung individu dengan keterbatasan kognitif.', '3']
# ['Integrasi dengan platform media sosial dapat memberikan dukungan tambahan.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di tempat kerja.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di lingkungan penjara.', '3']
# ['Tersedia opsi untuk mengakses materi edukasi yang disesuaikan dengan kelompok usia.', '3']
# ['Konten aplikasi dapat mencakup informasi tentang perawatan kesehatan mental.', '3']
# ['Integrasi dengan layanan konsultasi medis online terkait TBC dapat diperluas.', '3']
# ['Aplikasi ini memberikan wawasan tentang risiko penularan TBC di komunitas terpencil.', '3']
# ['Menyajikan informasi tentang cara mendukung kampanye kesadaran TBC di lingkungan keluarga.', '3']
# ['Tersedia opsi untuk menghubungkan pengguna dengan kelompok pendukung lokal.', '3']
# ['Konten aplikasi dapat memperhatikan aspek keberlanjutan dalam pencegahan TBC.', '3']
# ['Responsivitas antarmuka pengguna dapat ditingkatkan untuk pengalaman pengguna yang lebih baik.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kelompok usia lanjut dalam menghadapi TBC.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di daerah dengan keterbatasan akses kesehatan.', '3']
# ['Tersedia opsi untuk mengakses sumber daya tambahan untuk mendukung kelompok rentan.', '3']
# ['Konten aplikasi dapat mencakup informasi tentang peran teknologi dalam pencegahan TBC.', '3']
# ['Integrasi dengan webinar atau konferensi online dapat membantu penyebaran informasi lebih efektif.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di daerah terpencil.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '3']
# ['Tersedia opsi untuk menghubungkan pengguna dengan kelompok pendukung online.', '3']
# ['Konten aplikasi dapat memasukkan informasi tentang pengobatan alternatif yang diterima secara luas.', '3']
# ['Responsivitas antarmuka pengguna dapat ditingkatkan untuk mendukung pengguna dengan keterbatasan teknologi.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di tempat-tempat berisiko tinggi.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '3']
# ['Tersedia opsi untuk mengakses sumber daya tambahan untuk mendukung kelompok rentan.', '3']
# ['Konten aplikasi dapat mencakup informasi tentang peran teknologi dalam pencegahan TBC.', '3']
# ['Integrasi dengan webinar atau konferensi online dapat membantu penyebaran informasi lebih efektif.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di daerah terpencil.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '3']
# ['Tersedia opsi untuk menghubungkan pengguna dengan kelompok pendukung online.', '3']
# ['Konten aplikasi dapat memasukkan informasi tentang pengobatan alternatif yang diterima secara luas.', '3']
# ['Responsivitas antarmuka pengguna dapat ditingkatkan untuk mendukung pengguna dengan keterbatasan teknologi.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di tempat-tempat berisiko tinggi.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '3']
# ['Tersedia opsi untuk mengakses sumber daya tambahan untuk mendukung kelompok rentan.', '3']
# ['Konten aplikasi dapat mencakup informasi tentang peran teknologi dalam pencegahan TBC.', '3']
# ['Integrasi dengan webinar atau konferensi online dapat membantu penyebaran informasi lebih efektif.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di daerah terpencil.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '3']
# ['Tersedia opsi untuk menghubungkan pengguna dengan kelompok pendukung online.', '3']
# ['Konten aplikasi dapat memasukkan informasi tentang pengobatan alternatif yang diterima secara luas.', '3']
# ['Responsivitas antarmuka pengguna dapat ditingkatkan untuk mendukung pengguna dengan keterbatasan teknologi.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di tempat-tempat berisiko tinggi.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '3']
# ['Tersedia opsi untuk mengakses sumber daya tambahan untuk mendukung kelompok rentan.', '3']
# ['Konten aplikasi dapat mencakup informasi tentang peran teknologi dalam pencegahan TBC.', '3']
# ['Integrasi dengan webinar atau konferensi online dapat membantu penyebaran informasi lebih efektif.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di daerah terpencil.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '3']
# ['Tersedia opsi untuk menghubungkan pengguna dengan kelompok pendukung online.', '3']
# ['Konten aplikasi dapat memasukkan informasi tentang pengobatan alternatif yang diterima secara luas.', '3']
# ['Responsivitas antarmuka pengguna dapat ditingkatkan untuk mendukung pengguna dengan keterbatasan teknologi.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di tempat-tempat berisiko tinggi.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '3']
# ['Tersedia opsi untuk mengakses sumber daya tambahan untuk mendukung kelompok rentan.', '3']
# ['Konten aplikasi dapat mencakup informasi tentang peran teknologi dalam pencegahan TBC.', '3']
# ['Integrasi dengan webinar atau konferensi online dapat membantu penyebaran informasi lebih efektif.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di daerah terpencil.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '3']
# ['Tersedia opsi untuk menghubungkan pengguna dengan kelompok pendukung online.', '3']
# ['Konten aplikasi dapat memasukkan informasi tentang pengobatan alternatif yang diterima secara luas.', '3']
# ['Responsivitas antarmuka pengguna dapat ditingkatkan untuk mendukung pengguna dengan keterbatasan teknologi.', '3']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di tempat-tempat berisiko tinggi.', '3']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '3']
# ['Tersedia opsi untuk mengakses sumber daya tambahan untuk mendukung kelompok rentan.', '3']
# ['Konten aplikasi dapat mencakup informasi tentang peran teknologi dalam pencegahan TBC.', '3']
# ['Integrasi dengan webinar atau konferensi online dapat membantu penyebaran informasi lebih efektif.', '3']
# ['Saya rasa aplikasi ini memiliki potensi besar, tapi masih perlu beberapa perbaikan.', '3']
# ['TBC cukup baik, tetapi masih ada beberapa bug yang perlu diperbaiki.', '3']
# ['Saya suka ide di balik aplikasi ini, tetapi antarmuka penggunaannya agak membingungkan.', '3']
# ['Fungsionalitasnya lumayan, tapi butuh lebih banyak fitur untuk membuatnya lebih menarik.', '3']
# ['Sobat TBC layak dicoba, meskipun masih perlu disempurnakan.', '3']
# ['Rating 3 cukup adil, karena masih ada beberapa aspek yang perlu ditingkatkan.', '3']
# ['Aplikasi ini bisa jadi lebih baik dengan penambahan opsi kustomisasi.', '3']
# ['Sobat TBC membantu, tetapi navigasinya agak sulit dimengerti.', '3']
# ['Saya suka bagaimana aplikasi ini menyediakan informasi, tetapi ada bug yang mengganggu.', '3']
# ['Perbaiki beberapa masalah teknis, dan aplikasi ini bisa menjadi pilihan yang bagus.', '3']
# ['Rating 3 sesuai, karena ada beberapa fitur yang kurang intuitif.', '3']
# ['Antarmuka pengguna perlu ditingkatkan agar lebih ramah pengguna.', '3']
# ['Aplikasi ini memiliki potensi besar, tapi butuh lebih banyak pekerjaan.', '3']
# ['Sobat TBC bagus untuk informasi dasar, tetapi butuh lebih banyak konten.', '3']
# ['Butuh pembaruan lebih lanjut untuk meningkatkan performa aplikasi ini.', '3']
# ['Saya berharap ada opsi untuk mengatur notifikasi agar lebih mudah diikuti.', '3']
# ['Rating 3 cukup wajar, karena masih ada beberapa kesalahan yang harus diperbaiki.', '3']
# ['Aplikasi ini layak dicoba, tapi perlu ditingkatkan untuk bersaing dengan yang lain.', '3']
# ['Sobat TBC memberikan informasi yang berguna, tetapi ada beberapa kesalahan tipografi.', '3']
# ['Navigasi dalam aplikasi ini bisa lebih lancar dengan beberapa perbaikan.', '3']
# ['Saya berharap ada lebih banyak fitur sosial untuk berinteraksi dengan pengguna lain.', '3']
# ['Perlu peningkatan pada kecepatan penggunaan aplikasi.', '3']
# ['Sobat TBC memiliki konsep bagus, tetapi masih membutuhkan polishing.', '3']
# ['Butuh lebih banyak pilihan kustomisasi agar sesuai dengan preferensi pengguna.', '3']
# ['Aplikasi ini bermanfaat, tapi masih perlu perbaikan dalam hal tata letak.', '3']
# ['Saya senang dengan fungsionalitas dasarnya, tapi perlu lebih banyak konten bermanfaat.', '3']
# ['Rating 3 cocok, tapi butuh lebih banyak tutorial untuk memandu pengguna baru.', '3']
# ['Sobat TBC membutuhkan lebih banyak interaktivitas agar lebih menarik.', '3']
# ['Perbaiki beberapa bug dan aplikasi ini bisa menjadi yang terbaik.', '3']
# ['Antarmuka pengguna membingungkan, tetapi kontennya informatif.', '3']
# ['Rating 3 setuju, tapi tolong tambahkan lebih banyak fitur untuk pembaruan mendatang.', '3']
# ['Aplikasi ini layak dicoba, tetapi butuh perbaikan pada kinerja.', '3']
# ['Saya berharap ada lebih banyak konten lokal untuk menarik pengguna lokal.', '3']
# ['Perlu lebih banyak opsi filter untuk menyaring informasi dengan lebih baik.', '3']
# ['Sobat TBC memenuhi harapan, tapi ada beberapa fitur yang tidak berfungsi dengan baik.', '3']
# ['Rating 3 pantas, tapi aplikasi ini perlu lebih ramah pengguna.', '3']
# ['Saya suka bagaimana aplikasi ini memberikan update terbaru, tapi perlu lebih cepat.', '3']
# ['Navigasi yang tidak terlalu intuitif membuat pengguna kesulitan menemukan fitur tertentu.', '3']
# ['Sobat TBC memiliki potensi besar, tetapi performanya kurang stabil.', '3']
# ['Rating 3 sesuai, tapi aplikasi ini membutuhkan sentuhan desain yang lebih baik.', '3']
# ['Fitur pencarian membutuhkan peningkatan agar lebih akurat.', '3']
# ['Saya suka konsepnya, tetapi beberapa bagian aplikasi ini terasa kurang responsif.', '3']
# ['Sobat TBC memberikan informasi yang berguna, tetapi antarmuka pengguna perlu disederhanakan.', '3']
# ['Rating 3 cocok, tapi perlu lebih banyak pilihan tema.', '3']
# ['Butuh lebih banyak tutorial untuk membantu pengguna memahami fungsionalitas aplikasi.', '3']
# ['Aplikasi ini bisa lebih baik dengan penambahan fitur komunitas aktif.', '3']
# ['Sobat TBC memerlukan lebih banyak opsi personalisasi untuk membuat pengguna betah.', '3']
# ['Rating 3 adil, tetapi beberapa link di dalam aplikasi tidak berfungsi.', '3']
# ['Perbaiki beberapa masalah teknis dan aplikasi ini bisa menjadi yang hebat.', '3']
# ['Aplikasi ini memiliki potensi, tetapi perlu ditingkatkan agar lebih bersaing.', '3']
# ['Rating 3 sesuai, tetapi perlu lebih banyak dukungan pelanggan.', '3']
# ['Sobat TBC memberikan informasi yang bagus, tetapi perlu lebih banyak opsi berbagi.', '3']
# ['Aplikasi ini perlu peningkatan pada kecepatan pemuatan konten.', '3']
# ['Rating 3 wajar, tapi perlu perbaikan pada tampilan visual.', '3']
# ['Navigasinya agak rumit, tetapi informasinya sangat berguna.', '3']
# ['Sobat TBC memiliki potensi, tetapi perlu diperbarui secara berkala.', '3']
# ['Rating 3 sesuai, tapi ada beberapa gangguan iklan yang tidak diinginkan.', '3']
# ['Aplikasi ini membutuhkan integrasi sosial yang lebih baik untuk meningkatkan interaktivitas.', '3']
# ['Sobat TBC memberikan pandangan yang baik, tetapi butuh lebih banyak fitur prediksi.', '3']
# ['Rating 3 setuju, tapi perlu lebih banyak opsi bahasa.', '3']
# ['Aplikasi ini memberikan informasi yang cukup, tetapi perlu lebih banyak gambar dan grafik.', '3']
# ['Navigasinya membingungkan pada awalnya, tetapi pengguna akan terbiasa setelah beberapa kali menggunakan.', '3']
# ['Rating 3 cocok, tetapi aplikasi ini memerlukan dukungan offline.', '3']
# ['Sobat TBC memberikan kabar terbaru, tetapi perlu lebih banyak konten berbasis fakta.', '3']
# ['Aplikasi ini berguna, tetapi adakah rencana untuk memperluas cakupan berita?', '3']
# ['Rating 3 adil, tetapi perlu pembaruan lebih sering.', '3']
# ['Navigasi yang rumit membuat saya agak kesulitan menemukan fitur yang saya butuhkan.', '3']
# ['Sobat TBC perlu lebih banyak integrasi dengan platform lain untuk pengalaman yang lebih menyeluruh.', '3']
# ['Rating 3 sesuai, tetapi aplikasi ini membutuhkan peningkatan keamanan.', '3']
# ['Aplikasi ini memiliki potensi, tetapi butuh lebih banyak pembaruan untuk memperbaiki kekurangannya.', '3']
# ['Aplikasi ini sangat bermanfaat. Banyak ilmu dan pengetahuan. Saran saya pada tab forum bisa ga kita bikin status yang ada fotonya kayak medsos lainnya bgtu.', '5']
# ['Alhamdulillah sy sangat brterimah kasih .tadi nya sy eg penularan TBC..skarang Alhamdulliah uda tau sedikit demi sedikit..dan pencegah nya juga..trmksh semua nya..', '5']
# ...
# ['Tersedia opsi untuk menyumbangkan atau mendukung organisasi kesehatan.', '5']
# ['Memberikan informasi tentang peran nutrisi dalam mendukung pengobatan TBC.', '5']
# ['Aplikasi ini memberikan pandangan tentang risiko penularan TBC di berbagai wilayah.', '5']
# ['Tersedia opsi untuk berlangganan konten eksklusif untuk pembaruan terkini.', '5']
# ['Memberikan informasi tentang cara mendukung penderita TBC selama pengobatan.', '5']
# ['Aplikasi ini memberikan pemahaman tentang kebijakan pencegahan TBC di tingkat pemerintahan.', '5']
# ['Tersedia opsi untuk berpartisipasi dalam penelitian atau survei terkait TBC.', '5']
# ['Menyajikan informasi tentang peran komunitas dalam pencegahan TBC.', '5']
# ['Suka sekali', '5']
# ['Tersedia opsi untuk menghubungi tim medis melalui fitur obrolan langsung.', '5']
# ['Memberikan informasi tentang cara mendukung pendidikan kesadaran TBC di sekolah.', '5']
# ['Aplikasi ini memberikan panduan untuk memahami hasil tes TBC.', '5']
# ['Tersedia opsi untuk mencari dukungan psikologis melalui aplikasi.', '5']
# ['Menyajikan informasi tentang kebijakan penanggulangan TBC di fasilitas penjara.', '5']
# ['Aplikasi ini memberikan panduan untuk memahami dampak ekonomi bagi penderita TBC.', '5']
# ['Tersedia opsi untuk mengakses forum atau komunitas online penderita TBC.', '5']
# ['Memberikan informasi tentang cara mendukung program vaksinasi TBC di komunitas.', '5']
# ['Aplikasi ini memberikan panduan bagi mereka yang ingin berkontribusi dalam riset TBC.', '5']
# ['Tersedia opsi untuk menyaring konten berdasarkan kebutuhan kesehatan individu.', '5']
# ['Memberikan informasi tentang cara mendukung kampanye kesadaran TBC di lingkungan kerja.', '5']
# ['Aplikasi ini memberikan pemahaman tentang hubungan antara HIV dan TBC.', '5']
# ['Tersedia opsi untuk mencari dokter spesialis TBC di wilayah tertentu.', '5']
# ['Menyajikan informasi tentang cara mendukung kampanye kesadaran TBC di media sosial.', '5']
# ['Aplikasi ini memberikan panduan tentang cara melibatkan keluarga dalam perawatan penderita TBC.', '5']
# ['Tersedia opsi untuk mendapatkan saran langsung dari ahli melalui sesi konsultasi online.', '5']
# ['Memberikan informasi tentang upaya global untuk memerangi TBC di berbagai sektor.', '5']
# ['Aplikasi ini memberikan pemahaman tentang dampak TBC terhadap kesehatan mental.', '5']
# ['Tersedia opsi untuk mencari bantuan keuangan bagi penderita TBC.', '5']
# ['Waw, menyajikan informasi yang sangat mendalam tentang peran masyarakat dalam mendukung penderita TBC.', '5']
# ['Bagus banget, aplikasi ini memberikan panduan yang sangat komprehensif untuk memahami risiko penularan TBC di tempat kerja.', '5']
# ['Suka sekali, tersedia opsi luar biasa untuk berpartisipasi dalam kegiatan olahraga atau acara kesadaran TBC.', '5']
# ['Keren, memberikan informasi yang sangat jelas tentang cara mendukung kampanye kesadaran TBC di sekolah.', '5']
# ['Waw, aplikasi ini memberikan panduan yang sangat mendalam untuk memahami dampak sosial dan psikologis TBC.', '5']
# ['Bagus banget, tersedia opsi untuk menyaring informasi berdasarkan tingkat keparahan gejala.', '5']
# ['Suka sekali, menyajikan informasi yang sangat relevan tentang cara mendukung penderita TBC yang menghadapi stigma.', '5']
# ['Keren, aplikasi ini memberikan pemahaman yang sangat baik tentang perawatan kesehatan lanjutan bagi penderita TBC.', '5']
# ['Waw, tersedia opsi yang luar biasa untuk mendapatkan bantuan dalam mencari dukungan masyarakat.', '5']
# ['Bagus banget, memberikan informasi yang sangat jelas tentang cara mendukung penderita TBC selama dan setelah pengobatan.', '5']
# ['Suka sekali, aplikasi ini memberikan panduan yang sangat mendalam untuk memahami peran kebiasaan sehari-hari dalam pencegahan TBC.', '5']
# ['Keren, tersedia opsi yang luar biasa untuk mencari informasi tentang kebijakan kesehatan TBC di tingkat nasional.', '5']
# ['Waw, menyajikan informasi yang sangat relevan tentang cara mendukung penderita TBC dalam mengatasi tantangan ekonomi.', '5']
# ['Bagus banget, aplikasi ini memberikan pemahaman yang sangat baik tentang risiko penularan TBC di kalangan anak-anak.', '5']
# ['Suka sekali, tersedia opsi yang luar biasa untuk mendapatkan sumber daya tambahan untuk mendukung penderita TBC.', '5']
# ['Memberikan informasi tentang cara mendukung program pencegahan TBC di lingkungan masyarakat.', '5']
# ['Aplikasi ini memberikan panduan yang jelas tentang gejala TBC.', '5']
# ['Kontennya sangat informatif dan mendalam.', '5']
# ['Antarmukanya sangat ramah dan mudah digunakan.', '5']
# ['Fitur pencarian membantu menemukan informasi dengan cepat.', '5']
# ['Artikel-artikelnya sangat relevan dan terkini.', '5']
# ['Grafik dan ilustrasi membantu memahami informasi dengan lebih baik.', '5']
# ['Aplikasi ini memberikan pemahaman yang baik tentang penanganan TBC.', '5']
# ['Tersedia dalam beberapa bahasa, memudahkan akses global.', '5']
# ['Konten aplikasi disusun dengan baik dan mudah diikuti.', '5']
# ['Bagus banget, fitur bookmark memudahkan untuk menyimpan informasi penting.', '5']
# ['Waw, aplikasi memberikan solusi praktis yang sangat efektif untuk pencegahan penyebaran TBC.', '5']
# ['Keren, statistik dan data disajikan dengan sangat jelas dan mudah dimengerti.', '5']
# ['Suka sekali, aplikasi ini tetap terhubung dengan sumber informasi medis terkini.', '5']
# ['Waw, tampilan aplikasi responsif dan menarik secara visual.', '5']
# ['Bagus banget, integrasi dengan forum atau diskusi pengguna sangat memperkaya pengalaman.', '5']
# ['Suka sekali, memberikan informasi yang sangat relevan tentang obat-obatan yang umum digunakan.', '5']
# ['Keren, pembaruan konten berkala benar-benar menjaga keaktualitasan informasi.', '5']
# ['Waw, tersedia offline, memungkinkan akses tanpa koneksi internet.', '5']
# ['Bagus banget, aplikasi ini mendukung pencarian fasilitas kesehatan terdekat.', '5']
# ['Suka sekali, memberikan informasi yang sangat jelas tentang vaksinasi TBC.', '5']
# ['Waw, tersedia opsi untuk menghubungi profesional medis melalui aplikasi.', '5']
# ['Bagus banget, aplikasi ini memperkenalkan konsep penyebab dan penyebaran TBC dengan sangat baik.', '5']
# ['Keren, memberikan panduan langkah demi langkah yang sangat komprehensif untuk pengobatan TBC.', '5']
# ['Suka sekali, menyajikan informasi medis dengan bahasa yang sangat mudah dipahami.', '5']
# ['Tersedia ulasan atau testimoni pengguna yang memberikan perspektif positif.', '5']
# ['Konten aplikasi disajikan secara terstruktur dan mudah dipahami.', '5']
# ['Aplikasi ini memberikan saran praktis untuk merawat penderita TBC di rumah.', '5']
# ['Menyajikan informasi tentang risiko penularan TBC di berbagai lingkungan.', '5']
# ['Tersedia opsi untuk berpartisipasi dalam kampanye kesadaran TBC.', '5']
# ['Aplikasi ini memberikan pemahaman yang cukup baik tentang TBC.', '5']
# ['Menyajikan informasi tentang peran vaksinasi dalam pencegahan TBC.', '5']
# ['Tersedia opsi untuk berlangganan newsletter guna mendapatkan pembaruan.', '5']
# ['Aplikasi ini memberikan informasi tentang program pencegahan TBC di masyarakat.', '5']
# ['Tersedia opsi untuk menghubungi tim dukungan pelanggan aplikasi.', '5']
# ['Bagus banget, memberikan wawasan yang sangat penting tentang upaya global untuk memerangi TBC.', '5']
# ['Waw, konten aplikasi disajikan dengan bahasa yang sangat netral dan mudah dicerna.', '5']
# ['Keren, aplikasi ini memberikan informasi yang sangat relevan tentang penelitian terbaru mengenai TBC.', '5']
# ['Suka sekali, tersedia opsi yang luar biasa untuk mendukung organisasi kesehatan dengan sumbangan.', '5']
# ['Waw, menyajikan informasi yang sangat jelas tentang cara mendukung individu dengan TBC.', '5']
# ['Bagus banget, aplikasi ini memberikan perspektif yang sangat baik tentang dampak sosial TBC.', '5']
# ['Keren, tersedia opsi yang luar biasa untuk berbagi informasi atau artikel melalui media sosial.', '5']
# ['Suka sekali, memberikan informasi yang sangat penting tentang perawatan kesehatan mental bagi penderita TBC.', '5']
# ['Waw, aplikasi ini memberikan panduan yang sangat baik bagi keluarga yang merawat penderita TBC.', '5']
# ['Bagus banget, menyajikan informasi yang sangat relevan tentang dampak TBC terhadap sistem kekebalan tubuh.', '5']
# ['Pokoknya suka banget', '5']
# ['Memberikan informasi tentang penanganan TBC pada anak-anak.', '5']
# ['Aplikasi ini memberikan panduan tentang perawatan diri bagi penderita TBC.', '5']
# ['Tersedia opsi untuk mencari fasilitas kesehatan yang melayani TBC.', '5']
# ['Menyajikan informasi tentang konsekuensi jangka panjang dari TBC.', '5']
# ['Aplikasi ini memberikan informasi tentang dampak TBC terhadap kehamilan.', '5']
# ['Tersedia opsi untuk mengajukan pertanyaan kepada ahli melalui aplikasi.', '5']
# ['Memberikan informasi tentang risiko penularan TBC melalui kontak dekat.', '5']
# ['Aplikasi ini memberikan panduan untuk mendeteksi dini gejala TBC.', '5']
# ['Tersedia opsi untuk mengakses materi edukasi untuk penyuluhan.', '5']
# ['Menyajikan informasi tentang cara mendukung kampanye kesadaran TBC.', '5']
# ['Aplikasi ini memberikan informasi tentang pengobatan alternatif yang umum.', '5']
# ['Tersedia opsi untuk menyumbangkan atau mendukung organisasi kesehatan.', '5']
# ['Memberikan informasi tentang peran nutrisi dalam mendukung pengobatan TBC.', '5']
# ['Aplikasi ini memberikan pandangan tentang risiko penularan TBC di berbagai wilayah.', '5']
# ['Tersedia opsi untuk berlangganan konten eksklusif untuk pembaruan terkini.', '5']
# ['Memberikan informasi tentang cara mendukung penderita TBC selama pengobatan.', '5']
# ['Aplikasi ini memberikan pemahaman tentang kebijakan pencegahan TBC di tingkat pemerintahan.', '5']
# ['Tersedia opsi untuk berpartisipasi dalam penelitian atau survei terkait TBC.', '5']
# ['Bagus, Menyajikan informasi tentang peran komunitas dalam pencegahan TBC.', '5']
# ['Aplikasi ini memberikan panduan bagi mereka yang melakukan perjalanan ke daerah risiko TBC.', '5']
# ['Tersedia opsi untuk menghubungi tim medis melalui fitur obrolan langsung.', '5']
# ['Memberikan informasi tentang cara mendukung pendidikan kesadaran TBC di sekolah.', '5']
# ['Aplikasi ini memberikan panduan untuk memahami hasil tes TBC.', '5']
# ['Tersedia opsi untuk mencari dukungan psikologis melalui aplikasi.', '5']
# ['Menyajikan informasi tentang kebijakan penanggulangan TBC di fasilitas penjara.', '5']
# ['Aplikasi ini memberikan panduan untuk memahami dampak ekonomi bagi penderita TBC.', '5']
# ['Tersedia opsi untuk mengakses sesi konsultasi online dengan ahli TBC.', '5']
# ['Memberikan informasi tentang peran lingkungan kerja dalam pencegahan TBC.', '5']
# ['Aplikasi ini memberikan pemahaman tentang risiko penularan TBC di tempat umum.', '5']
# ['Tersedia opsi untuk berpartisipasi dalam kegiatan kesadaran TBC di komunitas lokal.', '5']
# ['Menyajikan informasi tentang cara mendukung penderita TBC dalam mengatasi stigma.', '5']
# ['Waw, aplikasi ini memberikan panduan yang luar biasa untuk memahami peran keluarga dalam perawatan penderita TBC.', '5']
# ['Keren, tersedia opsi untuk mendapatkan bantuan keuangan bagi penderita TBC.', '5']
# ['Suka sekali, memberikan informasi tentang cara mendukung kampanye kesadaran TBC di media sosial.', '5']
# ['Bagus banget, aplikasi ini memberikan pemahaman tentang hubungan antara HIV dan TBC.', '5']
# ['Waw, tersedia opsi untuk mencari dokter spesialis TBC di wilayah tertentu.', '5']
# ['Keren, menyajikan informasi tentang cara mendukung program vaksinasi TBC di komunitas.', '5']
# ['Suka sekali, aplikasi ini memberikan panduan bagi mereka yang ingin berkontribusi dalam riset TBC.', '5']
# ['Bagus banget, tersedia opsi untuk menyaring konten berdasarkan kebutuhan kesehatan individu.', '5']
# ['Waw, memberikan informasi tentang cara mendukung kampanye kesadaran TBC di lingkungan kerja.', '5']
# ['Keren, aplikasi ini memberikan pemahaman tentang dampak TBC terhadap kesehatan mental.', '5']
# ['Suka sekali, tersedia opsi untuk mencari bantuan keuangan bagi penderita TBC.', '5']
# ['Bagus banget, menyajikan informasi tentang peran masyarakat dalam mendukung penderita TBC.', '5']
# ['Waw, aplikasi ini memberikan panduan untuk memahami risiko penularan TBC di tempat kerja.', '5']
# ['Keren, tersedia opsi untuk berpartisipasi dalam kegiatan olahraga atau acara kesadaran TBC.', '5']
# ['Suka sekali, memberikan informasi tentang cara mendukung kampanye kesadaran TBC di sekolah.', '5']
# ['Aplikasi ini memberikan panduan untuk memahami dampak sosial dan psikologis TBC.', '5']
# ['Tersedia opsi untuk menyaring informasi berdasarkan tingkat keparahan gejala.', '5']
# ['Menyajikan informasi tentang cara mendukung penderita TBC yang menghadapi stigma.', '5']
# ['Aplikasi ini memberikan pemahaman tentang perawatan kesehatan lanjutan bagi penderita TBC.', '5']
# ['Tersedia opsi untuk mendapatkan saran langsung dari ahli melalui sesi konsultasi online.', '5']
# ['Memberikan informasi tentang upaya global untuk memerangi TBC di berbagai sektor.', '5']
# ['Aplikasi ini memberikan pemahaman tentang risiko penularan TBC di kalangan anak-anak.', '5']
# ['Tersedia opsi untuk mendapatkan bantuan dalam mencari dukungan masyarakat.', '5']
# ['Keren', '5']
# ['Aplikasi ini memberikan panduan untuk memahami peran kebiasaan sehari-hari dalam pencegahan TBC.', '5']
# ['Tersedia opsi untuk mencari informasi tentang kebijakan kesehatan TBC di tingkat nasional.', '5']
# ['Bangus Banget', '5']
# ['Aplikasi ini memberikan pemahaman tentang risiko penularan TBC di kalangan anak-anak.', '5']
# ['Tersedia opsi untuk mendapatkan sumber daya tambahan untuk mendukung penderita TBC.', '5']
# ['Memberikan informasi tentang cara mendukung program pencegahan TBC di lingkungan masyarakat.', '5']
# ['Aplikasi ini memberikan panduan untuk memahami risiko penularan TBC di tempat-tempat berisiko tinggi.', '5']
# ['Sangat Berguna', '5']
# ['Bagus banget, konten aplikasi dapat mencakup informasi yang sangat relevan tentang peran teknologi dalam pencegahan TBC.', '5']
# ['Waw, integrasi dengan webinar atau konferensi online dapat membantu penyebaran informasi lebih efektif.', '5']
# ['Keren, aplikasi ini memberikan panduan yang sangat baik tentang cara mendukung kampanye kesadaran TBC di daerah terpencil.', '5']
# ['Suka sekali, menyajikan informasi yang sangat jelas tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '5']
# ['Bagus banget, tersedia opsi yang luar biasa untuk menghubungkan pengguna dengan kelompok pendukung online.', '5']
# ['Waw, konten aplikasi dapat memasukkan informasi tentang pengobatan alternatif yang diterima secara luas.', '5']
# ['Keren, responsivitas antarmuka pengguna dapat ditingkatkan untuk mendukung pengguna dengan keterbatasan teknologi.', '5']
# ['Suka sekali, aplikasi ini memberikan panduan yang sangat baik tentang cara mendukung kampanye kesadaran TBC di tempat-tempat berisiko tinggi.', '5']
# ['Bagus banget, menyajikan informasi yang sangat jelas tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '5']
# ['Waw, tersedia opsi yang luar biasa untuk mengakses sumber daya tambahan untuk mendukung kelompok rentan.', '5']
# ['Keren, konten aplikasi dapat mencakup informasi yang sangat relevan tentang peran teknologi dalam pencegahan TBC.', '5']
# ['Suka sekali, integrasi dengan webinar atau konferensi online dapat membantu penyebaran informasi lebih efektif.', '5']
# ['Suka Banget', '5']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '5']
# ['Tersedia opsi untuk menghubungkan pengguna dengan kelompok pendukung online.', '5']
# ['Konten aplikasi dapat memasukkan informasi tentang pengobatan alternatif yang diterima secara luas.', '5']
# ['Responsivitas antarmuka pengguna dapat ditingkatkan untuk mendukung pengguna dengan keterbatasan teknologi.', '5']
# ['Aplikasi ini memberikan panduan tentang cara mendukung kampanye kesadaran TBC di tempat-tempat berisiko tinggi.', '5']
# ['Menyajikan informasi tentang risiko penularan TBC di tempat-tempat berisiko tinggi.', '5']
# ['Tersedia opsi untuk mengakses sumber daya tambahan untuk mendukung kelompok rentan.', '5']
# ['Konten aplikasi dapat mencakup informasi tentang peran teknologi dalam pencegahan TBC.', '5']
# ['waw keren banget', '5']

# %%
path_data_sentimen = "/content/drive/MyDrive/Kuliah/Tugas & Materi/Semester 5/Sistem Cerdas/Prak_Avriansyah Bahtiar/Revisi Deployment Model Sentiment Analysis/datasetnew3.csv"
data_sentiment = pd.read_csv(path_data_sentimen, sep=",", header=[0], encoding="UTF-8")

# %% [markdown]
# ##Labeling

# %%
data_sentiment.head()
# Out:
#                                              Reviews  Rating
# 0  Sebenernya ini aplikasi biasa saja hanya saja,...       1
# 1  Kak maaf mau tanya, kan waktu di halaman yang ...       1
# 2  Aplikasikannya belum siap, loadingnya tidak ad...       1
# 3  Aneh padahal daftar sudah benar malah disalahk...       1
# 4  Aplikasi tidak guna hanya loading saja.. Padah...       1

# %%
def pelabelan(rate):
  if rate == 3:
    return 0
  elif rate < 3:
    return -1
  elif rate > 3:
    return 1

data_sentiment['Label'] = data_sentiment['Rating'].apply(pelabelan)
data_sentiment.head()
# Out:
#                                              Reviews  Rating  Label
# 0  Sebenernya ini aplikasi biasa saja hanya saja,...       1     -1
# 1  Kak maaf mau tanya, kan waktu di halaman yang ...       1     -1
# 2  Aplikasikannya belum siap, loadingnya tidak ad...       1     -1
# 3  Aneh padahal daftar sudah benar malah disalahk...       1     -1
# 4  Aplikasi tidak guna hanya loading saja.. Padah...       1     -1

# %%
data_reviews = data_sentiment['Reviews']
print (data_reviews[:4])
# Out:
# 0    Sebenernya ini aplikasi biasa saja hanya saja,...
# 1    Kak maaf mau tanya, kan waktu di halaman yang ...
# 2    Aplikasikannya belum siap, loadingnya tidak ad...
# 3    Aneh padahal daftar sudah benar malah disalahk...
# Name: Reviews, dtype: object

# %% [markdown]
# #**Preprocessing**

# %% [markdown]
# ##Casefolding

# %% [markdown]
# Proses mengubah semua karakter huruf pada sebuah kalimat menjadi huruf kecil atau huruf besar. Case folding yang dilakukan yaitu mengubah seluruh dataset menjadi huruf kecil.

# %%
data_casefolding = data_reviews.str.lower()
data_casefolding.head()
# Out:
# 0    sebenernya ini aplikasi biasa saja hanya saja,...
# 1    kak maaf mau tanya, kan waktu di halaman yang ...
# 2    aplikasikannya belum siap, loadingnya tidak ad...
# 3    aneh padahal daftar sudah benar malah disalahk...
# 4    aplikasi tidak guna hanya loading saja.. padah...
# Name: Reviews, dtype: object

# %% [markdown]
# ##Filtering

# %% [markdown]
# Proses dalam menghilangkan karakter-karakter illegal.
#
# Contoh : %, &, >, (,
# {, ], 1-9, @uluwatu, http://...

# %%
#filtering url -> menggunakan list comprehension dan menggunakan regular expression re.sub mengganti url dengan spasi
filtering_url = [re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", ulasan) for ulasan in data_casefolding]

#filtering cont -> menggunakan list comprehension, kata cont(continued) dianggap sebagai noise dalam proses analisis data
filtering_cont = [re.sub(r'\(cont\)'," ", Reviews)for Reviews in filtering_url]

#filtering punctuatuion -> menggunakan list comprehension untuk menghapus tanda baca dari setiap ulasan
filtering_punctuation = [re.sub('[!"”#$%&’()*+,-./:;<=>?@[\]^_`{|}~]', ' ', Reviews) for Reviews in filtering_cont]  #hapus simbol'[!#?,.:";@()-_/\']'

#filtering tagger -> menghapus #tagger dan mengganti tagar dengan spasi
filtering_tagger = [re.sub(r'#([^\s]+)', '', Reviews) for Reviews in filtering_punctuation]

#filtering numeric -> menghapus angka dari setiap ulasan dalam dataset dengan spasi
filtering_numeric = [re.sub(r'\d+', ' ', Reviews) for Reviews in filtering_tagger]

data_filtering = pd.Series(filtering_numeric) #pandas series

print (data_filtering[:4])
#print (data_filtering) #jika ingin mencetak semua data_filtering
# Out:
# 0    sebenernya ini aplikasi biasa saja hanya saja ...
# 1    kak maaf mau tanya  kan waktu di halaman yang ...
# 2    aplikasikannya belum siap  loadingnya tidak ad...
# 3    aneh padahal daftar sudah benar malah disalahk...
# dtype: object

# %% [markdown]
# Dengan melakukan langkah-langkah diatas,teks telah dibersihkan dari URL, kata "(cont)", tanda baca, tagar, dan angka. Langkah-langkah diatas dapat membantu dalam meningkatkan kualitas data dan mencegah noise yang tidak diinginkan sebelum melakukan analisis lebih lanjut atau membangun model.

# %% [markdown]
# ##Tokenization

# %% [markdown]
# Proses untuk memecah dokumen teks menjadi token. Tokenisasi memiliki kemampuan untuk memecah dokumen menjadi kata, frasa, simbol atau elemen lain yang memiliki makna. Ada 2 cara yaitu word dan tweettokenizer.

# %%
import nltk
nltk.download('punkt') #model tokenisasi kata
from nltk.tokenize import word_tokenize

#tokenisasi kata pada setiap baris
data_tokens = [word_tokenize(line) for line in data_filtering]
print(data_tokens)
# Out:
# [['sebenernya', 'ini', 'aplikasi', 'biasa', 'saja', 'hanya', 'saja', 'saya', 'mendownload', 'aplikasi', 'ini', 'karena', 'diwajibkan', 'oleh', 'sekolah', 'dan', 'masalahnya', 'aplikasi', 'ini', 'mengambil', 'data', 'pribadi', 'yang', 'tentu', 'saja', 'saya', 'keberatan', 'kalau', 'ingin', 'membantu', 'seseorang', 'ayolah', 'membantu', 'dengan', 'ikhlas', 'dan', 'jagan', 'malah', 'mengambil', 'data', 'pribadi', 'seseorang'], ['kak', 'maaf', 'mau', 'tanya', 'kan', 'waktu', 'di', 'halaman', 'yang', 'ada', 'tulisan', 'username', 'emain', 'dan', 'password', 'kok', 'setelah', 'dimasukan', 'kata', 'katanya', 'ke', 'kolom', 'itu', 'waktu', 'mau', 'daftar', 'kok', 'gak', 'bisa', 'daftar', 'y', 'kak', 'palah', 'ada', 'tulisan', 'username', 'not', 'found'], ['aplikasikannya', 'belum', 'siap', 'loadingnya', 'tidak', 'ada', 'ampun', 'lama', 'banget', 'cape', 'nunggunya', 'server', 'over', 'load', 'dan', 'belum', 'siap', 'persiapkan', 'dulu'], ['aneh', 'padahal', 'daftar', 'sudah', 'benar', 'malah', 'disalahkan', 'aplikasi', 'tidak', 'bermutu'], ['aplikasi', 'tidak', 'guna', 'hanya', 'loading', 'saja', 'padahal', 'sinyal', 'wifi', 'kencang'], ['aplikasi', 'ngelag', 'ga', 'bermutu', 'mau', 'dikasih', 'ratting', 'tinggi', 'benerin', 'dulu', 'aplikasinya', 'bos', 'baru', 'sebarkan', 'sampah'], ['username', 'sudah', 'digunakan', 'padahal', 'udah', 'ganti', 'username', 'yang', 'panjang', 'dan', 'susah', 'tapi', 'tetep', 'ga', 'bisa'], ['ini', 'gimna', 'udh', 'masuk', 'tapi', 'pas', 'logout', 'mau', 'masuk', 'lagi', 'pedahal', 'username', 'sama', 'password', 'nya', 'sama', 'bnr', 'tpi', 'not', 'fot', 'mlu'], ['kebanyakan', 'bug', 'sangat', 'mengecewakan'], ['susah', 'banget', 'register', 'nya', 'daritadi', 'gagal', 'terus', 'tulisannya', 'alert', 'gagal', 'mendapatkan', 'token'], ['aplikasi', 'sulit', 'di', 'gunakan', 'saya', 'gak', 'suka', 'ribettt', 'banget', 'knp', 'gak', 'daftar', 'ofline', 'saja'], ['uhm', 'untuk', 'daftar', 'aja', 'ribet', 'salah', 'username', 'emai', 'bermasalah', 'lah', 'ng', 'jelas'], ['ribet', 'saya', 'sekolah', 'diwajibkan', 'mendownload', 'aplikasi', 'ini', 'padahal', 'kan', 'memori', 'saya', 'penuh', 'saya', 'kasih', 'rating', 'bintang'], ['eror', 'mulu', 'gk', 'bisa', 'login', 'kadang²', 'over', 'load', 'server', 'kadang', '²', 'loading', 'nya', 'nunggu', 'abat', 'dulu'], ['aplikasi', 'nya', 'belum', 'siap', 'ga', 'bisa', 'daftar', 'masuk'], ['aplikasi', 'gk', 'bagus', 'programmer', 'naikin', 'bayarannya', 'jadi', 'juta', 'biar', 'bagus'], ['wkwwkwkwk', 'najis', 'lah', 'dipaksa', 'download', 'sama', 'sekolah', 'padahal', 'memori', 'udah', 'penuh', 'tapi', 'tetep', 'dipaksa'], ['gak', 'bisa', 'di', 'download', 'setiap', 'balik', 'lg', 'ke', 'awal'], ['bikin', 'apk', 'niat', 'dikit', 'ke', 'lol', 'susah', 'di', 'regis', 'susah', 'masuk', 'atau', 'cuman', 'mau', 'colong', 'data', 'doang'], ['app', 'cacad', 'hampir', 'beberapa', 'cacad', 'gk', 'beres', 'benerin', 'kek', 'masa', 'org', 'gk', 'bisa', 'masuk'], ['install', 'uninstall', 'berkali', 'kali', 'karena', 'pertama', 'buka', 'button', 'daftar', 'nya', 'ga', 'ada', 'dan', 'lgsg', 'diminta', 'login', 'r', 'u', 'st', 'pid', 'login', 'pake', 'apa', 'coba'], ['benerin', 'dong', 'aplikasi', 'nya', 'ini', 'mau', 'login', 'susah', 'banget', 'dan', 'lama'], ['aplikasi', 'nya', 'lemot', 'banget', 'lama', 'jadinya'], ['ga', 'jls', 'minta', 'reset', 'password', 'malah', 'ga', 'di', 'kirim²'], ['lemottt', 'dari', 'jam', 'lalu', 'masih', 'muter'], ['tidak', 'bisa', 'masuk', 'daftar'], ['ini', 'aplikasi', 'apa', 'tidak', 'bisa', 'bikin', 'saya', 'sehat', 'tidak', 'bisa', 'mabar', 'pula'], ['aplikasi', 'nya', 'ngelag', 'plis', 'diperbaiki'], ['lemot', 'banget', 'pas', 'mau', 'login'], ['gamenya', 'gak', 'seru', 'kontrolnya', 'ngelag'], ['ga', 'guna', 'ada', 'ada', 'aja', 'menuh', 'n', 'memori', 'aja', 'kalau', 'ga', 'dr', 'skolah', 'ogah', 'bnr'], ['disuruh', 'sekolah', 'ke', 'apk', 'sobat', 'tb', 'malah', 'bikin', 'jadi', 'sobat', 'tambah', 'puyeng', 'ama', 'ini', 'apk'], ['apk', ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ##Stopword Removal

# %% [markdown]
# Tahap pengambilan kata-kata penting dan membuang kata-kata yang dianggap tidak penting (Cara untuk membuang kata yang tidak penting). Stopword removal bertujuan untuk menghilangkan kata-kata yang sering muncul namun tidak memiliki kontribusi dalam proses analisis data.
# Contoh : dan, yang, di, ke, dll

# %%
# !pip install sastrawi
# Out:
# Requirement already satisfied: sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
factory = StopWordRemoverFactory()
ind_stopword = factory.get_stop_words()

#penedefinisian fungsi stopword
def stopword(line):
  temp = list()
  for word in line:
    if(len(word)>3):
      temp.append(word)
  return temp

data_katapenting = [stopword (line) for line in data_tokens]
print(data_katapenting)
# Out:
# [['sebenernya', 'aplikasi', 'biasa', 'saja', 'hanya', 'saja', 'saya', 'mendownload', 'aplikasi', 'karena', 'diwajibkan', 'oleh', 'sekolah', 'masalahnya', 'aplikasi', 'mengambil', 'data', 'pribadi', 'yang', 'tentu', 'saja', 'saya', 'keberatan', 'kalau', 'ingin', 'membantu', 'seseorang', 'ayolah', 'membantu', 'dengan', 'ikhlas', 'jagan', 'malah', 'mengambil', 'data', 'pribadi', 'seseorang'], ['maaf', 'tanya', 'waktu', 'halaman', 'yang', 'tulisan', 'username', 'emain', 'password', 'setelah', 'dimasukan', 'kata', 'katanya', 'kolom', 'waktu', 'daftar', 'bisa', 'daftar', 'palah', 'tulisan', 'username', 'found'], ['aplikasikannya', 'belum', 'siap', 'loadingnya', 'tidak', 'ampun', 'lama', 'banget', 'cape', 'nunggunya', 'server', 'over', 'load', 'belum', 'siap', 'persiapkan', 'dulu'], ['aneh', 'padahal', 'daftar', 'sudah', 'benar', 'malah', 'disalahkan', 'aplikasi', 'tidak', 'bermutu'], ['aplikasi', 'tidak', 'guna', 'hanya', 'loading', 'saja', 'padahal', 'sinyal', 'wifi', 'kencang'], ['aplikasi', 'ngelag', 'bermutu', 'dikasih', 'ratting', 'tinggi', 'benerin', 'dulu', 'aplikasinya', 'baru', 'sebarkan', 'sampah'], ['username', 'sudah', 'digunakan', 'padahal', 'udah', 'ganti', 'username', 'yang', 'panjang', 'susah', 'tapi', 'tetep', 'bisa'], ['gimna', 'masuk', 'tapi', 'logout', 'masuk', 'lagi', 'pedahal', 'username', 'sama', 'password', 'sama'], ['kebanyakan', 'sangat', 'mengecewakan'], ['susah', 'banget', 'register', 'daritadi', 'gagal', 'terus', 'tulisannya', 'alert', 'gagal', 'mendapatkan', 'token'], ['aplikasi', 'sulit', 'gunakan', 'saya', 'suka', 'ribettt', 'banget', 'daftar', 'ofline', 'saja'], ['untuk', 'daftar', 'ribet', 'salah', 'username', 'emai', 'bermasalah', 'jelas'], ['ribet', 'saya', 'sekolah', 'diwajibkan', 'mendownload', 'aplikasi', 'padahal', 'memori', 'saya', 'penuh', 'saya', 'kasih', 'rating', 'bintang'], ['eror', 'mulu', 'bisa', 'login', 'kadang²', 'over', 'load', 'server', 'kadang', 'loading', 'nunggu', 'abat', 'dulu'], ['aplikasi', 'belum', 'siap', 'bisa', 'daftar', 'masuk'], ['aplikasi', 'bagus', 'programmer', 'naikin', 'bayarannya', 'jadi', 'juta', 'biar', 'bagus'], ['wkwwkwkwk', 'najis', 'dipaksa', 'download', 'sama', 'sekolah', 'padahal', 'memori', 'udah', 'penuh', 'tapi', 'tetep', 'dipaksa'], ['bisa', 'download', 'setiap', 'balik', 'awal'], ['bikin', 'niat', 'dikit', 'susah', 'regis', 'susah', 'masuk', 'atau', 'cuman', 'colong', 'data', 'doang'], ['cacad', 'hampir', 'beberapa', 'cacad', 'beres', 'benerin', 'masa', 'bisa', 'masuk'], ['install', 'uninstall', 'berkali', 'kali', 'karena', 'pertama', 'buka', 'button', 'daftar', 'lgsg', 'diminta', 'login', 'login', 'pake', 'coba'], ['benerin', 'dong', 'aplikasi', 'login', 'susah', 'banget', 'lama'], ['aplikasi', 'lemot', 'banget', 'lama', 'jadinya'], ['minta', 'reset', 'password', 'malah', 'kirim²'], ['lemottt', 'dari', 'lalu', 'masih', 'muter'], ['tidak', 'bisa', 'masuk', 'daftar'], ['aplikasi', 'tidak', 'bisa', 'bikin', 'saya', 'sehat', 'tidak', 'bisa', 'mabar', 'pula'], ['aplikasi', 'ngelag', 'plis', 'diperbaiki'], ['lemot', 'banget', 'login'], ['gamenya', 'seru', 'kontrolnya', 'ngelag'], ['guna', 'menuh', 'memori', 'kalau', 'skolah', 'ogah'], ['disuruh', 'sekolah', 'sobat', 'malah', 'bikin', 'jadi', 'sobat', 'tambah', 'puyeng'], ['guna', 'download', 'karana', 'suruh', 'dari', 'sekolahan'], ['game', 'gabisa', 'mabar', 'gabisa', 'gacha', 'juga'], ['disuruh', 'setyo', 'download', 'aplikasinya', 'jadi', 'tolong', 'jadikan', 'brand', 'ambassador'], ['lemot', 'banget', 'kalo', 'siap', 'jangan', 'dipaksakan', 'donk'], ['aplikasi', 'sobat', 'bukannya', 'memudahkan', 'malah', 'menyusahkan'], ['bisa', 'cuma', 'bisa', 'ambil', 'data', 'pribadi', 'doang'], ['coba', 'sesuai', 'bintang', 'tambah'], ['aplikasi', 'loding', 'terus', 'jlek'], ['aplikasi', 'jelek', 'gabisa', 'mabar'], ['isinya', 'kata', 'alert', 'semua'], ['jelek'], ['bilkin', 'ribet', 'hapus', 'aplikasi', 'bisa', 'bikin', 'aplikasi', 'penting'], ['aplikasi', 'memaksa', 'aplikasi', 'tidak', 'guna'], ['susah', 'masu ...

# %% [markdown]
# ## Slangword to Standword

# %% [markdown]
# Mengganti semua kata slang ke dalam bentuk standarnya dengan proses konversi slang word to standar word.
#
# Contoh : Bkn (slang/tdk baku) Bukan (Baku)

# %%
#slang word
path_dataslang = open("kamus kata baku 1.csv")
dataslang = pd.read_csv(path_dataslang, encoding = 'utf-8',header=None, sep=";")

def replaceSlang(word):
  if word in list(dataslang[0]):
    indexslang = list(dataslang[0]).index(word)
    return dataslang[1][indexslang]
  else:
    return word

reviews_formal = []
for data in data_tokens:
  data_clean = [replaceSlang(word) for word in data]
  reviews_formal.append(data_clean)
len_reviews_formal = len(reviews_formal)
print(reviews_formal)
len_reviews_formal
# Out:
# [['sebenarnya', 'ini', 'aplikasi', 'biasa', 'saja', 'hanya', 'saja', 'saya', 'mendownload', 'aplikasi', 'ini', 'karena', 'diwajibkan', 'oleh', 'sekolah', 'dan', 'masalahnya', 'aplikasi', 'ini', 'mengambil', 'data', 'pribadi', 'yang', 'tentu', 'saja', 'saya', 'keberatan', 'kalau', 'ingin', 'membantu', 'seseorang', 'ayolah', 'membantu', 'dengan', 'ikhlas', 'dan', 'jagan', 'malah', 'mengambil', 'data', 'pribadi', 'seseorang'], ['kak', 'maaf', 'mau', 'tanya', 'kan', 'waktu', 'di', 'halaman', 'yang', 'ada', 'tulisan', 'username', 'emain', 'dan', 'password', 'kok', 'setelah', 'dimasukan', 'kata', 'katanya', 'ke', 'kolom', 'itu', 'waktu', 'mau', 'daftar', 'kok', 'tidak', 'bisa', 'daftar', 'ya', 'kak', 'palah', 'ada', 'tulisan', 'username', 'tidak', 'found'], ['aplikasikannya', 'belum', 'siap', 'loadingnya', 'tidak', 'ada', 'ampun', 'lama', 'banget', 'capek', 'nunggunya', 'server', 'over', 'load', 'dan', 'belum', 'siap', 'persiapkan', 'dulu'], ['aneh', 'padahal', 'daftar', 'sudah', 'benar', 'malah', 'disalahkan', 'aplikasi', 'tidak', 'bermutu'], ['aplikasi', 'tidak', 'guna', 'hanya', 'loading', 'saja', 'padahal', 'sinyal', 'wifi', 'kencang'], ['aplikasi', 'ngelag', 'tidak', 'bermutu', 'mau', 'dikasih', 'ratting', 'tinggi', 'benerin', 'dulu', 'aplikasinya', 'bos', 'baru', 'sebarkan', 'sampah'], ['username', 'sudah', 'digunakan', 'padahal', 'sudah', 'ganti', 'username', 'yang', 'panjang', 'dan', 'susah', 'tapi', 'tetap', 'tidak', 'bisa'], ['ini', 'bagaimana', 'sudah', 'masuk', 'tapi', 'pas', 'logout', 'mau', 'masuk', 'lagi', 'pedahal', 'username', 'sama', 'password', 'nya', 'sama', 'benar', 'tapi', 'tidak', 'fot', 'malu'], ['kebanyakan', 'bug', 'sangat', 'mengecewakan'], ['susah', 'banget', 'register', 'nya', 'daritadi', 'gagal', 'terus', 'tulisannya', 'alert', 'gagal', 'mendapatkan', 'token'], ['aplikasi', 'sulit', 'di', 'gunakan', 'saya', 'tidak', 'suka', 'ribettt', 'banget', 'kenapa', 'tidak', 'daftar', 'ofline', 'saja'], ['uhm', 'untuk', 'daftar', 'saja', 'ribet', 'salah', 'username', 'emai', 'bermasalah', 'lah', 'ng', 'jelas'], ['ribet', 'saya', 'sekolah', 'diwajibkan', 'mendownload', 'aplikasi', 'ini', 'padahal', 'kan', 'memori', 'saya', 'penuh', 'saya', 'kasih', 'rating', 'bintang'], ['eror', 'terus', 'tidak', 'bisa', 'login', 'kadang²', 'over', 'load', 'server', 'kadang', '²', 'loading', 'nya', 'menunggu', 'abat', 'dulu'], ['aplikasi', 'nya', 'belum', 'siap', 'tidak', 'bisa', 'daftar', 'masuk'], ['aplikasi', 'tidak', 'bagus', 'programmer', 'naikin', 'bayarannya', 'jadi', 'juta', 'biar', 'bagus'], ['wkwwkwkwk', 'najis', 'lah', 'dipaksa', 'download', 'sama', 'sekolah', 'padahal', 'memori', 'sudah', 'penuh', 'tapi', 'tetap', 'dipaksa'], ['tidak', 'bisa', 'di', 'download', 'setiap', 'balik', 'lagi', 'ke', 'awal'], ['membuat', 'apk', 'niat', 'sedikit', 'ke', 'tertawa', 'susah', 'di', 'regis', 'susah', 'masuk', 'atau', 'cuma', 'mau', 'colong', 'data', 'cuma'], ['app', 'cacad', 'hampir', 'beberapa', 'cacad', 'tidak', 'selesai', 'benerin', 'kayak', 'masa', 'orang', 'tidak', 'bisa', 'masuk'], ['install', 'uninstall', 'berkali', 'kali', 'karena', 'pertama', 'buka', 'button', 'daftar', 'nya', 'tidak', 'ada', 'dan', 'langsung', 'diminta', 'login', 'r', 'untuk', 'st', 'pid', 'login', 'pakai', 'apa', 'coba'], ['benerin', 'dong', 'aplikasi', 'nya', 'ini', 'mau', 'login', 'susah', 'banget', 'dan', 'lama'], ['aplikasi', 'nya', 'lemot', 'banget', 'lama', 'jadinya'], ['tidak', 'jls', 'meminta', 'reset', 'password', 'malah', 'tidak', 'di', 'kirim²'], ['lemottt', 'dari', 'jam', 'lalu', 'masih', 'putar'], ['tidak', 'bisa', 'masuk', 'daftar'], ['ini', 'aplikasi', 'apa', 'tidak', 'bisa', 'membuat', 'saya', 'sehat', 'tidak', 'bisa', 'mabar', 'pula'], ['aplikasi', 'nya', 'ngelag', 'mohon', 'diperbaiki'], ['lemot', 'banget', 'pas', 'mau', 'login'], ['gamenya', 'tidak', 'seru', 'kontrolnya', 'ngelag'], ['tidak', 'guna', 'ada', 'ada', 'saja', 'menuh', 'dan', 'memori', 'saja', 'kalau', 'tidak', 'dari', 'sekolah', 'ogah', 'benar'], ['disuruh', 'sekolah', 'ke' ...
# 930

# %%
nltk.download('stopwords')
default_stop_words = nltk.corpus.stopwords.words('indonesian')
stopwords = set(default_stop_words)

def removeStopWords(line, stopwords):
  words = []
  for word in line:
    word=str(word)
    word = word.strip()
    if word not in stopwords and word != "" and word != "&":
      words.append(word)

  return words
data_notstopword = [removeStopWords(line,stopwords) for line in reviews_formal]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ##Steamming

# %% [markdown]
# Proses stemming dilakukan dengan menghapus imbuhan, baik awalan maupun akhiran dari suatu kata untuk mendapatkan kata dasarnya.

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
factory = StemmerFactory()
ind_stemmer =factory.create_stemmer()

def stemmer(line):
  temp = list()
  for word in line:
      word = ind_stemmer.stem(word)
      temp.append(word)
  return temp

reviews_dasar = [stemmer (line) for line in reviews_formal]

#cetak 2 baris pertama
print(reviews_dasar[:2])
# Out:
# [['benar', 'ini', 'aplikasi', 'biasa', 'saja', 'hanya', 'saja', 'saya', 'mendownload', 'aplikasi', 'ini', 'karena', 'wajib', 'oleh', 'sekolah', 'dan', 'masalah', 'aplikasi', 'ini', 'ambil', 'data', 'pribadi', 'yang', 'tentu', 'saja', 'saya', 'berat', 'kalau', 'ingin', 'bantu', 'orang', 'ayo', 'bantu', 'dengan', 'ikhlas', 'dan', 'jagan', 'malah', 'ambil', 'data', 'pribadi', 'orang'], ['kak', 'maaf', 'mau', 'tanya', 'kan', 'waktu', 'di', 'halaman', 'yang', 'ada', 'tulis', 'username', 'emain', 'dan', 'password', 'kok', 'telah', 'masuk', 'kata', 'kata', 'ke', 'kolom', 'itu', 'waktu', 'mau', 'daftar', 'kok', 'tidak', 'bisa', 'daftar', 'ya', 'kak', 'palah', 'ada', 'tulis', 'username', 'tidak', 'found']]

# %% [markdown]
# ##Lemmatization

# %% [markdown]
# Untuk membersihkan dan mengolah ulang (preprocessing). Lemmatization bertujuan untuk mengembalikan kata ke bentuk dasarnya, sementara stemming mencoba untuk menghapus afiks dari kata-kata. (lebih powerfull)
#
# Contohnya, "running" bisa diubah menjadi "run" melalui lemmatization atau stemming.

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data_sentiment['Reviews'][1]
# Out:
# 'Kak maaf mau tanya, kan waktu di halaman yang ada tulisan username/emain dan password kok setelah dimasukan kata katanya ke kolom itu waktu mau daftar kok gak bisa daftar y kak, palah ada tulisan username not found'

# %%
#pengembalian kata ke bentuk dasar
lemma = WordNetLemmatizer()
stemmer = PorterStemmer()

def CleanReview(txt):
  txt = re.sub(r'http\S+', ' ', txt) #mengganti semua url dengan spasi
  txt = re.sub(r'[^a-zA-Z]', ' ', txt) #mengganti karakter non-alfabet dengan spasi
  txt = str(txt).lower() #mengubah huruf besar ke kecil
  txt = word_tokenize(txt) #teks menjadi token
  txt = [item for item in txt if item not in data_notstopword] #menghapus kata yg ga dipake (stopword)
  txt = [lemma.lemmatize(word=w, pos='v')for w in txt] #mengembalikan kata ke bentuk dasar
  txt = [i for i in txt if len(i) > 2] #menghapus kata-kata yang terlalu pendek
  txt = ' '.join(txt)
  return txt
data_sentiment['CleanReview'] = data_sentiment['Reviews'].apply(CleanReview)

data_sentiment.head()
# Out:
#                                              Reviews  Rating  Label  \
# 0  Sebenernya ini aplikasi biasa saja hanya saja,...       1     -1
# 1  Kak maaf mau tanya, kan waktu di halaman yang ...       1     -1
# 2  Aplikasikannya belum siap, loadingnya tidak ad...       1     -1
# 3  Aneh padahal daftar sudah benar malah disalahk...       1     -1
# 4  Aplikasi tidak guna hanya loading saja.. Padah...       1     -1
#
#                                          CleanReview
# 0  sebenernya ini aplikasi biasa saja hanya saja ...
# 1  kak maaf mau tanya kan waktu halaman yang ada ...
# 2  aplikasikannya belum siap loadingnya tidak ada...
# 3  aneh padahal daftar sudah benar malah disalahk...
# 4  aplikasi tidak guna hanya load saja padahal si...

# %% [markdown]
# Tujuan dari tahap ini adalah untuk mempersiapkan teks agar dapat digunakan dengan lebih baik dalam pemrosesan atau pembuatan model machine learning, dengan menghilangkan noise, mengurangi dimensi, dan meningkatkan kualitas fitur.

# %% [markdown]
# #**Training Data and Split Data**

# %%
#Training data x_train, x_test, y_train, y_tes
x = data_sentiment ['CleanReview']
y = data_sentiment ['Label']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=4)
nama = "Model SVM dengan TF-IDF"

# %% [markdown]
# #**Feauture Extraction for Mechine Learning (SVM)**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline

# %%
# Membuat model SVM dengan TF-IDF sebagai fitur
model_svm = make_pipeline(TfidfVectorizer(), LinearSVC(C=0.75))

# %%
# Melatih model pada data training
model_svm.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('linearsvc', LinearSVC(C=0.75))])

# %%
# Melakukan prediksi pada data testing
y_pred = model_svm.predict(x_test)

# %% [markdown]
# #**Evaluasi Model**

# %%
# Evaluasi model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
# Menampilkan hasil evaluasi
print(f"{nama} - Akurasi: {accuracy:.2f}")
print(f"\nClassification Report:\n{classification_rep}")
print(f"\nConfusion Matrix:\n{conf_matrix}")
# Out:
# Model SVM dengan TF-IDF - Akurasi: 0.80
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.91      0.92      0.92        66
#            0       0.73      0.79      0.76        57
#            1       0.75      0.68      0.72        63
#
#     accuracy                           0.80       186
#    macro avg       0.80      0.80      0.80       186
# weighted avg       0.80      0.80      0.80       186
#
#
# Confusion Matrix:
# [[61  1  4]
#  [ 2 45 10]
#  [ 4 16 43]]

# %% [markdown]
# #**Deployment**

# %%
pickle.dump(model_svm, open('/content/drive/MyDrive/Kuliah/Tugas & Materi/Semester 5/Sistem Cerdas/Prak_Avriansyah Bahtiar/Revisi Deployment Model Sentiment Analysis/tfidf_{}_nvb.pkl'.format(nama), 'wb'))

# %%
model = pickle.load(open('/content/drive/MyDrive/Kuliah/Tugas & Materi/Semester 5/Sistem Cerdas/Prak_Avriansyah Bahtiar/Revisi Deployment Model Sentiment Analysis/tfidf_'+str(nama)+'_nvb.pkl','rb'))
pred_y_ = model.predict(x_test) #prediksi classification_report
label_test = y_test
print('\n'+'-'*45)
print('confusion matrix : ' + str(nama))
print('-'*45,'\n')
print(classification_report(label_test, pred_y_, labels=[-1, 0, 1]))
# Out:
# ---------------------------------------------
# confusion matrix : Model SVM dengan TF-IDF
# ---------------------------------------------
#
#               precision    recall  f1-score   support
#
#           -1       0.91      0.92      0.92        66
#            0       0.73      0.79      0.76        57
#            1       0.75      0.68      0.72        63
#
#     accuracy                           0.80       186
#    macro avg       0.80      0.80      0.80       186
# weighted avg       0.80      0.80      0.80       186
